# %% [markdown]
# # Creacion de DataFrames de Netflix

# %% [markdown]
# ## Lecturas archivos

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### api_netflix
# Informacion de las peliculas dada por la API. Sus columnas son:
# Las columnas nos entregan los siguientes datos:
# - `id`: Identificador de la pelicula en la API
# - `title`: Nombre de la pelicula
# - `year`: Año de estreno de la pelicula
# - `imdb_id`: Identificador de la pelicula en IMDB
# - `tmdb_id`: Identificador de la pelicula en TMDB
# - `tmdb_type`: Tipo del titulo en TMDB
# - `type`: Tipo del titulo en la API

# %%
dfnetflix = pd.read_csv('data/api_netflix.csv')
dfnetflix.head()
# Out:
#          id                             title  year     imdb_id  tmdb_id
# 0   1823218             The Woman in Cabin 10  2025   tt7130300  1290879
# 1  11042350         My Father, the BTK Killer  2025  tt38466379  1550785
# 2   1812460             She Walks in Darkness  2025  tt32129665  1275151
# 3   1996393                        Swim to Me  2025  tt34682204  1484640
# 4   1944218  Everybody Loves Me When I'm Dead  2025  tt35669054  1429750

# %% [markdown]
# ### imdb_basics
# Informacion basica de cada titulo en IMDB. Sus columnas son:
# - `tconst`: Id del titulo en IMDB
# - `titleType`: Tipo del titulo
# - `primaryTitle`: Nombre mas comun del titulo
# - `originalTitle`: Nombre original del titulo
# - `isAdult`: Bool que indica si es para adultos o no
# - `startYear`: Año de salida, en series es el año de comienzo de la serie
# - `endYear`: Año de fin de la serie
# - `runtimeMinutes`: Duracion del titulo en minutos
# - `genres`: Lista de generos del titulo

# %%
imdb_basics = pd.read_csv('tsv/title.basics.tsv', sep='\t')
imdb_basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short            Poor Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#    isAdult startYear endYear runtimeMinutes                    genres
# 0        0      1894      \N              1         Documentary,Short
# 1        0      1892      \N              5           Animation,Short
# 2        0      1892      \N              5  Animation,Comedy,Romance
# 3        0      1892      \N             12           Animation,Short
# 4        0      1893      \N              1                     Short

# %% [markdown]
# ### imdb_ratings
# Rating de cada pelicula en IMDB. Sus columnas son:
# - `tconst`: Id de IMDB
# - `averageRating`: Puntaje promedio dado por los votos
# - `numVotes`: Cantidad de votos

# %%
imdb_ratings = pd.read_csv('tsv/title.ratings.tsv', sep='\t')
imdb_ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2180
# 1  tt0000002            5.5       302
# 2  tt0000003            6.4      2254
# 3  tt0000004            5.2       194
# 4  tt0000005            6.2      2992

# %% [markdown]
# ### imdb_principals
# Trabajadores involucrados en cada titulo de IMDB (directores, productores, actores, etc.). Sus columnas son:
# - `tconst`: Id del titulo en IMDB
# - `ordering`: Id para enumerar a los trabajadores por titulo
# - `nconst`: Id de persona en IMDB
# - `category`: Categoria del rol que cumplio en el titulo
# - `job`: Trabajo que tenia en el titulo
# - `characters`: En caso de ser actor, muestra los nombres de los personajes que interpreta

# %%
imdb_principals = pd.read_csv('tsv/title.principals.tsv', sep='\t')
imdb_principals.head()
# Out:
#       tconst  ordering     nconst         category                      job  \
# 0  tt0000001         1  nm1588970             self                       \N
# 1  tt0000001         2  nm0005690         director                       \N
# 2  tt0000001         3  nm0005690         producer                 producer
# 3  tt0000001         4  nm0374658  cinematographer  director of photography
# 4  tt0000002         1  nm0721526         director                       \N
#
#   characters
# 0   ["Self"]
# 1         \N
# 2         \N
# 3         \N
# 4         \N

# %% [markdown]
# ### imdb_crew
# Directores y escritores de cada titulo en IMDB. Sus columnas son:
# - `tconst`: Id del titulo en IMDB
# - `directors`: Id de persona del director en IMDB
# - `writers`: Id de persona de los escritores en IMDB

# %%
imdb_crew = pd.read_csv('tsv/title.crew.tsv', sep='\t')
imdb_crew.head()
# Out:
#       tconst  directors    writers
# 0  tt0000001  nm0005690         \N
# 1  tt0000002  nm0721526         \N
# 2  tt0000003  nm0721526  nm0721526
# 3  tt0000004  nm0721526         \N
# 4  tt0000005  nm0005690         \N

# %% [markdown]
# ### imdb_name
# Este Dataframe contiene informacion de cada persona relacionada a titulos dentro de IMDB. Sus columnas son:
# - `nconst`: Id de la persona en IMDB
# - `primaryName`: Nombre por el que es mas conocida la persona
# - `birthYear`: Año de nacimiento de la persona
# - `deathYear`: Año de fallecimiento de la persona
# - `primaryProfession`: Los tres roles que mas suele cumplir en los titulos
# - `knownForTitle`: Titulos por los que es conocido

# %%
imdb_name = pd.read_csv('tsv/name.basics.tsv', sep='\t')
imdb_name.head()
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                     primaryProfession                           knownForTitles
# 0        actor,miscellaneous,producer  tt0050419,tt0072308,tt0027125,tt0025164
# 1  actress,soundtrack,archive_footage  tt0037382,tt0075213,tt0038355,tt0117057
# 2   actress,music_department,producer  tt0057345,tt0049189,tt0056404,tt0054452
# 3       actor,writer,music_department  tt0072562,tt0077975,tt0080455,tt0078723
# 4               writer,director,actor  tt0050986,tt0069467,tt0083922,tt0050976

# %% [markdown]
# ## Creacion de Dataframe principal

# %% [markdown]
# ### Join con `imdb_basics`

# %%
df_main1 = dfnetflix.merge(imdb_basics, how='left', left_on='imdb_id', right_on='tconst')
df_main1.head()
# Out:
#          id                             title  year     imdb_id  tmdb_id  \
# 0   1823218             The Woman in Cabin 10  2025   tt7130300  1290879
# 1  11042350         My Father, the BTK Killer  2025  tt38466379  1550785
# 2   1812460             She Walks in Darkness  2025  tt32129665  1275151
# 3   1996393                        Swim to Me  2025  tt34682204  1484640
# 4   1944218  Everybody Loves Me When I'm Dead  2025  tt35669054  1429750
#
#        tconst titleType                      primaryTitle  \
# 0   tt7130300     movie             The Woman in Cabin 10
# 1  tt38466379     movie         My Father, the BTK Killer
# 2  tt32129665     movie             She Walks in Darkness
# 3  tt34682204     movie                        Swim to Me
# 4  tt35669054     movie  Everybody Loves Me When I'm Dead
#
#                       originalTitle  isAdult startYear endYear runtimeMinutes  \
# 0             The Woman in Cabin 10      0.0      2025      \N             92
# 1         My Father, the BTK Killer      0.0      2025      \N             93
# 2         Un fantasma en la batalla      0.0      2025      \N            108
# 3                            Limpia      0.0      2025      \N            102
# 4  Everybody Loves Me When I'm Dead      0.0      2025      \N            128
#
#                    genres
# 0  Drama,Mystery,Thriller
# 1       Crime,Documentary
# 2  Drama,History,Thriller
# 3                   Drama
# 4                      \N

# %% [markdown]
# ### Join con `imdb_ratings`

# %%
df_main2 = df_main1.merge(imdb_ratings, how='left', left_on='imdb_id', right_on='tconst')
df_main2.head()
# Out:
#          id                             title  year     imdb_id  tmdb_id  \
# 0   1823218             The Woman in Cabin 10  2025   tt7130300  1290879
# 1  11042350         My Father, the BTK Killer  2025  tt38466379  1550785
# 2   1812460             She Walks in Darkness  2025  tt32129665  1275151
# 3   1996393                        Swim to Me  2025  tt34682204  1484640
# 4   1944218  Everybody Loves Me When I'm Dead  2025  tt35669054  1429750
#
#      tconst_x titleType                      primaryTitle  \
# 0   tt7130300     movie             The Woman in Cabin 10
# 1  tt38466379     movie         My Father, the BTK Killer
# 2  tt32129665     movie             She Walks in Darkness
# 3  tt34682204     movie                        Swim to Me
# 4  tt35669054     movie  Everybody Loves Me When I'm Dead
#
#                       originalTitle  isAdult startYear endYear runtimeMinutes  \
# 0             The Woman in Cabin 10      0.0      2025      \N             92
# 1         My Father, the BTK Killer      0.0      2025      \N             93
# 2         Un fantasma en la batalla      0.0      2025      \N            108
# 3                            Limpia      0.0      2025      \N            102
# 4  Everybody Loves Me When I'm Dead      0.0      2025      \N            128
#
#                    genres    tconst_y  averageRating  numVotes
# 0  Drama,Mystery,Thriller   tt7130300            5.9   16028.0
# 1       Crime,Documentary  tt38466379            6.2    1063.0
# 2  Drama,History,Thriller  tt32129665            7.4      70.0
# 3                   Drama  tt34682204            5.3     162.0
# 4                      \N         NaN            NaN       NaN

# %% [markdown]
# ### Join con `imdb_crew`

# %%
df_main3 = df_main2.merge(imdb_crew, how='left', left_on='imdb_id', right_on='tconst')
df_main3.head()
# Out:
#          id                             title  year     imdb_id  tmdb_id  \
# 0   1823218             The Woman in Cabin 10  2025   tt7130300  1290879
# 1  11042350         My Father, the BTK Killer  2025  tt38466379  1550785
# 2   1812460             She Walks in Darkness  2025  tt32129665  1275151
# 3   1996393                        Swim to Me  2025  tt34682204  1484640
# 4   1944218  Everybody Loves Me When I'm Dead  2025  tt35669054  1429750
#
#      tconst_x titleType                      primaryTitle  \
# 0   tt7130300     movie             The Woman in Cabin 10
# 1  tt38466379     movie         My Father, the BTK Killer
# 2  tt32129665     movie             She Walks in Darkness
# 3  tt34682204     movie                        Swim to Me
# 4  tt35669054     movie  Everybody Loves Me When I'm Dead
#
#                       originalTitle  isAdult startYear endYear runtimeMinutes  \
# 0             The Woman in Cabin 10      0.0      2025      \N             92
# 1         My Father, the BTK Killer      0.0      2025      \N             93
# 2         Un fantasma en la batalla      0.0      2025      \N            108
# 3                            Limpia      0.0      2025      \N            102
# 4  Everybody Loves Me When I'm Dead      0.0      2025      \N            128
#
#                    genres    tconst_y  averageRating  numVotes      tconst  \
# 0  Drama,Mystery,Thriller   tt7130300            5.9   16028.0   tt7130300
# 1       Crime,Documentary  tt38466379            6.2    1063.0  tt38466379
# 2  Drama,History,Thriller  tt32129665            7.4      70.0  tt32129665
# 3                   Drama  tt34682204            5.3     162.0  tt34682204
# 4                      \N         NaN            NaN       NaN  tt35669054
#
#    directors                                            writers
# 0  nm1404307  nm1100123,nm3143608,nm1404307,nm0296491,nm3405121
# 1  nm1341941                                                 \N
# 2  nm0246503                                          nm0246503
# 3  nm3049622                    nm10202287,nm3049622,nm15953578
# 4  nm1552261                                                 \N

# %% [markdown]
# ### Limpieza

# %% [markdown]
# #### Eliminar columnas
# Eliminamos columnas con informacion repetida o irrelevante

# %%
df_main4 = df_main3[['id', 'imdb_id', 'title', 'primaryTitle', 'originalTitle', 'titleType', 'year', 'startYear', 
                     'isAdult', 'runtimeMinutes', 'genres', 'averageRating', 'numVotes', 'directors', 'writers']]
df_main4.head()
# Out:
#          id     imdb_id                             title  \
# 0   1823218   tt7130300             The Woman in Cabin 10
# 1  11042350  tt38466379         My Father, the BTK Killer
# 2   1812460  tt32129665             She Walks in Darkness
# 3   1996393  tt34682204                        Swim to Me
# 4   1944218  tt35669054  Everybody Loves Me When I'm Dead
#
#                        primaryTitle                     originalTitle  \
# 0             The Woman in Cabin 10             The Woman in Cabin 10
# 1         My Father, the BTK Killer         My Father, the BTK Killer
# 2             She Walks in Darkness         Un fantasma en la batalla
# 3                        Swim to Me                            Limpia
# 4  Everybody Loves Me When I'm Dead  Everybody Loves Me When I'm Dead
#
#   titleType  year startYear  isAdult runtimeMinutes                  genres  \
# 0     movie  2025      2025      0.0             92  Drama,Mystery,Thriller
# 1     movie  2025      2025      0.0             93       Crime,Documentary
# 2     movie  2025      2025      0.0            108  Drama,History,Thriller
# 3     movie  2025      2025      0.0            102                   Drama
# 4     movie  2025      2025      0.0            128                      \N
#
#    averageRating  numVotes  directors  \
# 0            5.9   16028.0  nm1404307
# 1            6.2    1063.0  nm1341941
# 2            7.4      70.0  nm0246503
# 3            5.3     162.0  nm3049622
# 4            NaN       NaN  nm1552261
#
#                                              writers
# 0  nm1100123,nm3143608,nm1404307,nm0296491,nm3405121
# 1                                                 \N
# 2                                          nm0246503
# 3                    nm10202287,nm3049622,nm15953578
# 4                                                 \N

# %% [markdown]
# #### Correcion valores nulos y tipos de columnas

# %%
df_main5 = df_main4.replace(['\\N', np.nan, None], pd.NA)

# %%
df_main5.dtypes
# Out:
# id                 int64
# imdb_id           object
# title             object
# primaryTitle      object
# originalTitle     object
# titleType         object
# year               int64
# startYear         object
# isAdult           object
# runtimeMinutes    object
# genres            object
# averageRating     object
# numVotes          object
# directors         object
# writers           object
# dtype: object

# %%
df_main5['titleType'] = df_main5['titleType'].astype('category')
df_main5['startYear'] = df_main5['startYear'].astype('Int64')
df_main5['isAdult'] = df_main5['isAdult'].astype('Int64')
df_main5['runtimeMinutes'] = df_main5['runtimeMinutes'].astype('Int64')
df_main5['averageRating'] = df_main5['averageRating'].astype('Float64')
df_main5['numVotes'] = df_main5['numVotes'].astype('Int64')

# %%
df_main5.head()
# Out:
#          id     imdb_id                             title  \
# 0   1823218   tt7130300             The Woman in Cabin 10
# 1  11042350  tt38466379         My Father, the BTK Killer
# 2   1812460  tt32129665             She Walks in Darkness
# 3   1996393  tt34682204                        Swim to Me
# 4   1944218  tt35669054  Everybody Loves Me When I'm Dead
#
#                        primaryTitle                     originalTitle  \
# 0             The Woman in Cabin 10             The Woman in Cabin 10
# 1         My Father, the BTK Killer         My Father, the BTK Killer
# 2             She Walks in Darkness         Un fantasma en la batalla
# 3                        Swim to Me                            Limpia
# 4  Everybody Loves Me When I'm Dead  Everybody Loves Me When I'm Dead
#
#   titleType  year  startYear  isAdult  runtimeMinutes                  genres  \
# 0     movie  2025       2025        0              92  Drama,Mystery,Thriller
# 1     movie  2025       2025        0              93       Crime,Documentary
# 2     movie  2025       2025        0             108  Drama,History,Thriller
# 3     movie  2025       2025        0             102                   Drama
# 4     movie  2025       2025        0             128                    <NA>
#
#    averageRating  numVotes  directors  \
# 0            5.9     16028  nm1404307
# 1            6.2      1063  nm1341941
# 2            7.4        70  nm0246503
# 3            5.3       162  nm3049622
# 4           <NA>      <NA>  nm1552261
#
#                                              writers
# 0  nm1100123,nm3143608,nm1404307,nm0296491,nm3405121
# 1                                               <NA>
# 2                                          nm0246503
# 3                    nm10202287,nm3049622,nm15953578
# 4                                               <NA>

# %%
for i in ['genres', 'directors', 'writers']:
    df_main5[i] = df_main5[i].apply(lambda x: str(x).split(',') if pd.notna(x) else [])

df_main5.head()
# Out:
#          id     imdb_id                             title  \
# 0   1823218   tt7130300             The Woman in Cabin 10
# 1  11042350  tt38466379         My Father, the BTK Killer
# 2   1812460  tt32129665             She Walks in Darkness
# 3   1996393  tt34682204                        Swim to Me
# 4   1944218  tt35669054  Everybody Loves Me When I'm Dead
#
#                        primaryTitle                     originalTitle  \
# 0             The Woman in Cabin 10             The Woman in Cabin 10
# 1         My Father, the BTK Killer         My Father, the BTK Killer
# 2             She Walks in Darkness         Un fantasma en la batalla
# 3                        Swim to Me                            Limpia
# 4  Everybody Loves Me When I'm Dead  Everybody Loves Me When I'm Dead
#
#   titleType  year  startYear  isAdult  runtimeMinutes  \
# 0     movie  2025       2025        0              92
# 1     movie  2025       2025        0              93
# 2     movie  2025       2025        0             108
# 3     movie  2025       2025        0             102
# 4     movie  2025       2025        0             128
#
#                        genres  averageRating  numVotes    directors  \
# 0  [Drama, Mystery, Thriller]            5.9     16028  [nm1404307]
# 1        [Crime, Documentary]            6.2      1063  [nm1341941]
# 2  [Drama, History, Thriller]            7.4        70  [nm0246503]
# 3                     [Drama]            5.3       162  [nm3049622]
# 4                          []           <NA>      <NA>  [nm1552261]
#
#                                              writers
# 0  [nm1100123, nm3143608, nm1404307, nm0296491, n...
# 1                                                 []
# 2                                        [nm0246503]
# 3                [nm10202287, nm3049622, nm15953578]
# 4                                                 []

# %% [markdown]
# Valores NA

# %%
resultados = {}
for i in df_main5.columns:
    resultados[i] = df_main5[i].isna().sum()
resultados
# Out:
# {'id': np.int64(0),
#  'imdb_id': np.int64(0),
#  'title': np.int64(0),
#  'primaryTitle': np.int64(4),
#  'originalTitle': np.int64(4),
#  'titleType': np.int64(4),
#  'year': np.int64(0),
#  'startYear': np.int64(4),
#  'isAdult': np.int64(4),
#  'runtimeMinutes': np.int64(13),
#  'genres': np.int64(0),
#  'averageRating': np.int64(9),
#  'numVotes': np.int64(9),
#  'directors': np.int64(0),
#  'writers': np.int64(0)}

# %%
df_main5[pd.isna(df_main5['runtimeMinutes'])]
# Out:
#             id     imdb_id                                              title  \
# 19    11050026  tt36265413                                     Inside Furioza
# 34    11047294  tt38356685  Turn of the Tide: The Surreal Story of Rabo de...
# 1430   1628879   tt8066940                           Indian 2: Zero Tolerance
# 1683   1771964  tt29892095                                    Girl Haunts Boy
# 2114   1693330  tt15939090                                   Burning Patience
# 2285   1890136  tt35287639                              The Maximum Penalty 2
# 2683   1834116  tt32643879                                            Outside
# 2764   1556312   tt0106206                                      Aashik Aawara
# 2769   1899207  tt13079112                                  The Lockdown Plan
# 2773   1698365  tt15751968                                              Smile
# 2795   1625502  tt13836494            Pinkfong & Baby Shark's Space Adventure
# 2889  11046064  tt38221275        Nouvelle École et après : Réussir ou mourir
# 2892   1940869  tt37458102                  Uncredited: The Story of Passinho
#
#                                            primaryTitle  \
# 19                                        Furioza Again
# 34    Turn of the Tide: The Surreal Story of Rabo de...
# 1430                                           Indian 2
# 1683                                               <NA>
# 2114                                               <NA>
# 2285                                   La Pena Maxima 2
# 2683                                               <NA>
# 2764                                      Aashik Aawara
# 2769                                  The Lockdown Plan
# 2773                                              Smile
# 2795                                               <NA>
# 2889             Rhythm + Flow: France - After the Beat
# 2892          Passinho Foda - O Corre Por Trás da Dança
#
#                                          originalTitle  titleType  year  \
# 19                                       Furioza Again      movie  2025
# 34    Maré Branca: A Surreal História de Rabo de Peixe      movie  2025
# 1430                                          Indian 2      movie  2024
# 1683                                              <NA>        NaN  2024
# 2114                                              <NA>        NaN  2022
# 2285                                  La Pena Maxima 2      movie  2024
# 2683                                              <NA>        NaN  2024
# 2764                                     Aashik Aawara      movie  1993
# 2769                                 The Lockdown Plan  tvEpisode  2022
# 2773                                             Smile      movie  2022
# 2795                                              <NA>        NaN  2019
# 2889       Nouvelle École: Et après: Réussir ou mourir      movie  2025
# 2892         Passinho Foda - O Corre Por Trás da Dança      movie  2025
#
#       startYear  isAdult  runtimeMinutes                    genres  \
# 19         2025        0            <NA>                   [Drama]
# 34         2025        0            <NA>             [Documentary]
# 1430       2024        0            <NA>  [Action, Drama, Musical]
# 1683       <NA>     <NA>            <NA>                        []
# 2114       <NA>     <NA>            <NA>                        []
# 2285       2024        0            <NA>                  [Comedy]
# 2683       <NA>     <NA>            <NA>                        []
# 2764       1993        0            <NA>                   [Drama]
# 2769       2020        0            <NA>         [Comedy, Romance]
# 2773       2022        0            <NA>                  [Horror]
# 2795       <NA>     <NA>            <NA>                        []
# 2889       2025        0            <NA>             [Documentary]
# 2892       2025        0            <NA>      [Documentary, Sport]
#
#       averageRating  numVotes                directors  \
# 19             <NA>      <NA>              [nm2940110]
# 34             <NA>      <NA>             [nm13956670]
# 1430            3.8     16792              [nm0788171]
# 1683           <NA>      <NA>                       []
# 2114           <NA>      <NA>                       []
# 2285            5.5        74              [nm1357797]
# 2683           <NA>      <NA>                       []
# 2764            4.8       414              [nm0576494]
# 2769            6.5       102                       []
# 2773            4.3       155             [nm10076697]
# 2795           <NA>      <NA>                       []
# 2889            5.5         8             [nm14553571]
# 2892            7.7         6  [nm10193998, nm9792122]
#
#                                                 writers
# 19                                                   []
# 34                                          [nm2029700]
# 1430  [nm10171496, nm3328122, nm11805162, nm9731217,...
# 1683                                                 []
# 2114                                                 []
# 2285                                                 []
# 2683                                                 []
# 2764                             [nm0576494, nm1100075]
# 2769                                                 []
# 2773                                       [nm10076697]
# 2795                                                 []
# 2889                                                 []
# 2892                  [nm6936959, nm9060455, nm9181221]

# %%
df_main5[pd.isna(df_main5['averageRating'])]
# Out:
#             id     imdb_id                                              title  \
# 4      1944218  tt35669054                   Everybody Loves Me When I'm Dead
# 19    11050026  tt36265413                                     Inside Furioza
# 34    11047294  tt38356685  Turn of the Tide: The Surreal Story of Rabo de...
# 1683   1771964  tt29892095                                    Girl Haunts Boy
# 2114   1693330  tt15939090                                   Burning Patience
# 2130  11042008  tt38366532                              The Time That Remains
# 2391   1901595   tt0498396                                          The Twits
# 2683   1834116  tt32643879                                            Outside
# 2795   1625502  tt13836494            Pinkfong & Baby Shark's Space Adventure
#
#                                            primaryTitle  \
# 4                      Everybody Loves Me When I'm Dead
# 19                                        Furioza Again
# 34    Turn of the Tide: The Surreal Story of Rabo de...
# 1683                                               <NA>
# 2114                                               <NA>
# 2130                              The Time That Remains
# 2391                                          The Twits
# 2683                                               <NA>
# 2795                                               <NA>
#
#                                          originalTitle titleType  year  \
# 4                     Everybody Loves Me When I'm Dead     movie  2025
# 19                                       Furioza Again     movie  2025
# 34    Maré Branca: A Surreal História de Rabo de Peixe     movie  2025
# 1683                                              <NA>       NaN  2024
# 2114                                              <NA>       NaN  2022
# 2130                             The Time That Remains     movie  2025
# 2391                                         The Twits     movie  2025
# 2683                                              <NA>       NaN  2024
# 2795                                              <NA>       NaN  2019
#
#       startYear  isAdult  runtimeMinutes                          genres  \
# 4          2025        0             128                              []
# 19         2025        0            <NA>                         [Drama]
# 34         2025        0            <NA>                   [Documentary]
# 1683       <NA>     <NA>            <NA>                              []
# 2114       <NA>     <NA>            <NA>                              []
# 2130       2025        0             116       [Drama, Fantasy, Romance]
# 2391       2025        0              98  [Adventure, Animation, Comedy]
# 2683       <NA>     <NA>            <NA>                              []
# 2795       <NA>     <NA>            <NA>                              []
#
#       averageRating  numVotes                          directors  \
# 4              <NA>      <NA>                        [nm1552261]
# 19             <NA>      <NA>                        [nm2940110]
# 34             <NA>      <NA>                       [nm13956670]
# 1683           <NA>      <NA>                                 []
# 2114           <NA>      <NA>                                 []
# 2130           <NA>      <NA>                        [nm0019723]
# 2391           <NA>      <NA>  [nm1601882, nm2154609, nm4670728]
# 2683           <NA>      <NA>                                 []
# 2795           <NA>      <NA>                                 []
#
#                                 writers
# 4                                    []
# 19                                   []
# 34                          [nm2029700]
# 1683                                 []
# 2114                                 []
# 2130                                 []
# 2391  [nm1601882, nm5044246, nm0001094]
# 2683                                 []
# 2795                                 []

# %% [markdown]
# Duplicados

# %%
df_main5.duplicated('imdb_id').sum()
# Out:
# np.int64(0)

# %% [markdown]
# Analisis columnas

# %%
df_main5.describe()
# Out:
#                  id         year    startYear  isAdult  runtimeMinutes  \
# count  2.908000e+03  2908.000000       2904.0   2904.0          2895.0
# mean   1.581275e+06  2018.924347  2018.878788      0.0      108.786528
# std    9.168449e+05     7.290506     7.285463      0.0       22.508434
# min    1.660000e+02  1967.000000       1967.0      0.0            10.0
# 25%    1.412952e+06  2018.000000       2018.0      0.0            94.0
# 50%    1.620810e+06  2021.000000       2021.0      0.0           105.0
# 75%    1.697665e+06  2023.000000       2023.0      0.0           120.0
# max    1.105003e+07  2025.000000       2025.0      0.0           210.0
#
#        averageRating       numVotes
# count         2899.0         2899.0
# mean        6.180476   40037.418765
# std         1.047656  105053.375984
# min              1.6            6.0
# 25%              5.6         1828.5
# 50%              6.3         6289.0
# 75%              6.9        27807.5
# max              9.0      1725395.0

# %%
dfmain = df_main5

# %%
dfmain.to_csv('data/imdb_netflix.csv')

# %% [markdown]
# ## Creacion Dataframe personas

# %%
df_personas1 = dfmain.merge(imdb_principals, how='left', left_on='imdb_id', right_on='tconst')
df_personas1.head()
# Out:
#         id    imdb_id                  title           primaryTitle  \
# 0  1823218  tt7130300  The Woman in Cabin 10  The Woman in Cabin 10
# 1  1823218  tt7130300  The Woman in Cabin 10  The Woman in Cabin 10
# 2  1823218  tt7130300  The Woman in Cabin 10  The Woman in Cabin 10
# 3  1823218  tt7130300  The Woman in Cabin 10  The Woman in Cabin 10
# 4  1823218  tt7130300  The Woman in Cabin 10  The Woman in Cabin 10
#
#            originalTitle titleType  year  startYear  isAdult  runtimeMinutes  \
# 0  The Woman in Cabin 10     movie  2025       2025        0              92
# 1  The Woman in Cabin 10     movie  2025       2025        0              92
# 2  The Woman in Cabin 10     movie  2025       2025        0              92
# 3  The Woman in Cabin 10     movie  2025       2025        0              92
# 4  The Woman in Cabin 10     movie  2025       2025        0              92
#
#    ... averageRating  numVotes    directors  \
# 0  ...           5.9     16028  [nm1404307]
# 1  ...           5.9     16028  [nm1404307]
# 2  ...           5.9     16028  [nm1404307]
# 3  ...           5.9     16028  [nm1404307]
# 4  ...           5.9     16028  [nm1404307]
#
#                                              writers     tconst ordering  \
# 0  [nm1100123, nm3143608, nm1404307, nm0296491, n...  tt7130300      1.0
# 1  [nm1100123, nm3143608, nm1404307, nm0296491, n...  tt7130300      2.0
# 2  [nm1100123, nm3143608, nm1404307, nm0296491, n...  tt7130300      3.0
# 3  [nm1100123, nm3143608, nm1404307, nm0296491, n...  tt7130300      4.0
# 4  [nm1100123, nm3143608, nm1404307, nm0296491, n...  tt7130300      5.0
#
#       nconst category job            characters
# 0  nm0461136  actress  \N   ["Laura Blacklock"]
# 1  nm0001602    actor  \N   ["Richard Bullmer"]
# 2  nm2916966    actor  \N        ["Ben Morgan"]
# 3  nm1926861  actress  \N            ["Carrie"]
# 4  nm0539562    actor  \N  ["Dr. Robert Mehta"]
#
# [5 rows x 21 columns]

# %% [markdown]
# Eliminar Columnas

# %%
df_personas2 = df_personas1[['id', 'imdb_id', 'title', 'nconst', 'ordering', 'category', 'job', 'characters', 'primaryTitle',
                             'originalTitle', 'titleType', 'year', 'startYear', 'isAdult', 'runtimeMinutes', 'genres', 'averageRating',
                             'numVotes', 'directors', 'writers']]
df_personas2.head()
# Out:
#         id    imdb_id                  title     nconst  ordering category  \
# 0  1823218  tt7130300  The Woman in Cabin 10  nm0461136       1.0  actress
# 1  1823218  tt7130300  The Woman in Cabin 10  nm0001602       2.0    actor
# 2  1823218  tt7130300  The Woman in Cabin 10  nm2916966       3.0    actor
# 3  1823218  tt7130300  The Woman in Cabin 10  nm1926861       4.0  actress
# 4  1823218  tt7130300  The Woman in Cabin 10  nm0539562       5.0    actor
#
#   job            characters           primaryTitle          originalTitle  \
# 0  \N   ["Laura Blacklock"]  The Woman in Cabin 10  The Woman in Cabin 10
# 1  \N   ["Richard Bullmer"]  The Woman in Cabin 10  The Woman in Cabin 10
# 2  \N        ["Ben Morgan"]  The Woman in Cabin 10  The Woman in Cabin 10
# 3  \N            ["Carrie"]  The Woman in Cabin 10  The Woman in Cabin 10
# 4  \N  ["Dr. Robert Mehta"]  The Woman in Cabin 10  The Woman in Cabin 10
#
#   titleType  year  startYear  isAdult  runtimeMinutes  \
# 0     movie  2025       2025        0              92
# 1     movie  2025       2025        0              92
# 2     movie  2025       2025        0              92
# 3     movie  2025       2025        0              92
# 4     movie  2025       2025        0              92
#
#                        genres  averageRating  numVotes    directors  \
# 0  [Drama, Mystery, Thriller]            5.9     16028  [nm1404307]
# 1  [Drama, Mystery, Thriller]            5.9     16028  [nm1404307]
# 2  [Drama, Mystery, Thriller]            5.9     16028  [nm1404307]
# 3  [Drama, Mystery, Thriller]            5.9     16028  [nm1404307]
# 4  [Drama, Mystery, Thriller]            5.9     16028  [nm1404307]
#
#                                              writers
# 0  [nm1100123, nm3143608, nm1404307, nm0296491, n...
# 1  [nm1100123, nm3143608, nm1404307, nm0296491, n...
# 2  [nm1100123, nm3143608, nm1404307, nm0296491, n...
# 3  [nm1100123, nm3143608, nm1404307, nm0296491, n...
# 4  [nm1100123, nm3143608, nm1404307, nm0296491, n...

# %% [markdown]
# ### Arreglar valores nulos y columnas

# %%
df_personas3 = df_personas2.replace(['\\N', np.nan, None], pd.NA)
df_personas3.head()
# Out:
#         id    imdb_id                  title     nconst ordering category  \
# 0  1823218  tt7130300  The Woman in Cabin 10  nm0461136      1.0  actress
# 1  1823218  tt7130300  The Woman in Cabin 10  nm0001602      2.0    actor
# 2  1823218  tt7130300  The Woman in Cabin 10  nm2916966      3.0    actor
# 3  1823218  tt7130300  The Woman in Cabin 10  nm1926861      4.0  actress
# 4  1823218  tt7130300  The Woman in Cabin 10  nm0539562      5.0    actor
#
#     job            characters           primaryTitle          originalTitle  \
# 0  <NA>   ["Laura Blacklock"]  The Woman in Cabin 10  The Woman in Cabin 10
# 1  <NA>   ["Richard Bullmer"]  The Woman in Cabin 10  The Woman in Cabin 10
# 2  <NA>        ["Ben Morgan"]  The Woman in Cabin 10  The Woman in Cabin 10
# 3  <NA>            ["Carrie"]  The Woman in Cabin 10  The Woman in Cabin 10
# 4  <NA>  ["Dr. Robert Mehta"]  The Woman in Cabin 10  The Woman in Cabin 10
#
#   titleType  year  startYear  isAdult  runtimeMinutes  \
# 0     movie  2025       2025        0              92
# 1     movie  2025       2025        0              92
# 2     movie  2025       2025        0              92
# 3     movie  2025       2025        0              92
# 4     movie  2025       2025        0              92
#
#                        genres  averageRating  numVotes    directors  \
# 0  [Drama, Mystery, Thriller]            5.9     16028  [nm1404307]
# 1  [Drama, Mystery, Thriller]            5.9     16028  [nm1404307]
# 2  [Drama, Mystery, Thriller]            5.9     16028  [nm1404307]
# 3  [Drama, Mystery, Thriller]            5.9     16028  [nm1404307]
# 4  [Drama, Mystery, Thriller]            5.9     16028  [nm1404307]
#
#                                              writers
# 0  [nm1100123, nm3143608, nm1404307, nm0296491, n...
# 1  [nm1100123, nm3143608, nm1404307, nm0296491, n...
# 2  [nm1100123, nm3143608, nm1404307, nm0296491, n...
# 3  [nm1100123, nm3143608, nm1404307, nm0296491, n...
# 4  [nm1100123, nm3143608, nm1404307, nm0296491, n...

# %%
df_personas3.dtypes
# Out:
# id                   int64
# imdb_id             object
# title               object
# nconst              object
# ordering            object
# category            object
# job                 object
# characters          object
# primaryTitle        object
# originalTitle       object
# titleType         category
# year                 int64
# startYear            Int64
# isAdult              Int64
# runtimeMinutes       Int64
# genres              object
# averageRating      Float64
# numVotes             Int64
# directors           object
# writers             object
# dtype: object

# %%
df_personas3['ordering'] = df_personas3['ordering'].astype('Int64')
df_personas3['category'] = df_personas3['category'].astype('category')

# %% [markdown]
# ### Valores nulos

# %%
resultados = {}
for i in df_personas3.columns:
    resultados[i] = df_personas3[i].isna().sum()
resultados
# Out:
# {'id': np.int64(0),
#  'imdb_id': np.int64(0),
#  'title': np.int64(0),
#  'nconst': np.int64(6),
#  'ordering': np.int64(6),
#  'category': np.int64(6),
#  'job': np.int64(43264),
#  'characters': np.int64(31867),
#  'primaryTitle': np.int64(4),
#  'originalTitle': np.int64(4),
#  'titleType': np.int64(4),
#  'year': np.int64(0),
#  'startYear': np.int64(4),
#  'isAdult': np.int64(4),
#  'runtimeMinutes': np.int64(136),
#  'genres': np.int64(0),
#  'averageRating': np.int64(68),
#  'numVotes': np.int64(68),
#  'directors': np.int64(0),
#  'writers': np.int64(0)}

# %%
dfpersonas = df_personas3

# %%
dfpersonas.to_csv('data/personas_netflix.csv')
