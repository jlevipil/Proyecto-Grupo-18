# %% [markdown]
# # Creacion de DataFrames de Prime

# %% [markdown]
# ## Lecturas archivos

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### api_prime
# Informacion de las peliculas dada por la API. Sus columnas son:
# Las columnas nos entregan los siguientes datos:
# - `id`: Identificador de la pelicula en la API
# - `title`: Nombre de la pelicula
# - `year`: Año de estreno de la pelicula
# - `imdb_id`: Identificador de la pelicula en IMDB
# - `tmdb_id`: Identificador de la pelicula en TMDB
# - `tmdb_type`: Tipo del titulo en TMDB
# - `type`: Tipo del titulo en la API

# %%
dfprime = pd.read_csv('data/api_prime.csv')
dfprime.head()
# Out:
#          id                  title  year     imdb_id  tmdb_id
# 0  11001921  John Candy: I Like Me  2025  tt26683420  1492608
# 1   1882904   Maintenance Required  2025  tt33335602  1352755
# 2   1535445           Gladiator II  2024   tt9218128   558449
# 3   1532981             The Batman  2022   tt1877830   414906
# 4   1498670              Nosferatu  2024   tt5040012   426063

# %% [markdown]
# ### imdb_basics
# Informacion basica de cada titulo en IMDB. Sus columnas son:
# - `tconst`: Id del titulo en IMDB
# - `titleType`: Tipo del titulo
# - `primaryTitle`: Nombre mas comun del titulo
# - `originalTitle`: Nombre original del titulo
# - `isAdult`: Bool que indica si es para adultos o no
# - `startYear`: Año de salida, en series es el año de comienzo de la serie
# - `endYear`: Año de fin de la serie (No muy util ya que solo trabajaremos con peliculas)
# - `runtimeMinutes`: Duracion del titulo en minutos
# - `genres`: Lista de generos del titulo

# %%
imdb_basics = pd.read_csv('data/title.basics.tsv', sep='\t')
imdb_basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short            Poor Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#    isAdult startYear endYear runtimeMinutes                    genres
# 0        0      1894      \N              1         Documentary,Short
# 1        0      1892      \N              5           Animation,Short
# 2        0      1892      \N              5  Animation,Comedy,Romance
# 3        0      1892      \N             12           Animation,Short
# 4        0      1893      \N              1                     Short

# %% [markdown]
# ### imdb_ratings
# Rating de cada pelicula en IMDB. Sus columnas son:
# - `tconst`: Id de IMDB
# - `averageRating`: Puntaje promedio dado por los votos
# - `numVotes`: Cantidad de votos

# %%
imdb_ratings = pd.read_csv('data/title.ratings.tsv', sep='\t')
imdb_ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2178
# 1  tt0000002            5.5       299
# 2  tt0000003            6.4      2243
# 3  tt0000004            5.2       193
# 4  tt0000005            6.2      2986

# %% [markdown]
# ### imdb_principals
# Trabajadores involucrados en cada titulo de IMDB (directores, productores, actores, etc.). Sus columnas son:
# - `tconst`: Id del titulo en IMDB
# - `ordering`: Id para enumerar a los trabajadores por titulo
# - `nconst`: Id de persona en IMDB
# - `category`: Categoria del rol que cumplio en el titulo
# - `job`: Trabajo que tenia en el titulo
# - `characters`: En caso de ser actor, muestra los nombres de los personajes que interpreta

# %%
imdb_principals = pd.read_csv('data/title.principals.tsv', sep='\t')
imdb_principals.head()
# Out:
#       tconst  ordering     nconst         category                      job  \
# 0  tt0000001         1  nm1588970             self                       \N
# 1  tt0000001         2  nm0005690         director                       \N
# 2  tt0000001         3  nm0005690         producer                 producer
# 3  tt0000001         4  nm0374658  cinematographer  director of photography
# 4  tt0000002         1  nm0721526         director                       \N
#
#   characters
# 0   ["Self"]
# 1         \N
# 2         \N
# 3         \N
# 4         \N

# %% [markdown]
# ### imdb_crew
# Directores y escritores de cada titulo en IMDB. Sus columnas son:
# - `tconst`: Id del titulo en IMDB
# - `directors`: Id de persona del director en IMDB
# - `writers`: Id de persona de los escritores en IMDB

# %%
imdb_crew = pd.read_csv('data/title.crew.tsv', sep='\t')
imdb_crew.head()
# Out:
#       tconst  directors    writers
# 0  tt0000001  nm0005690         \N
# 1  tt0000002  nm0721526         \N
# 2  tt0000003  nm0721526  nm0721526
# 3  tt0000004  nm0721526         \N
# 4  tt0000005  nm0005690         \N

# %% [markdown]
# ### imdb_name
# Este Dataframe contiene informacion de cada persona relacionada a titulos dentro de IMDB. Sus columnas son:
# - `nconst`: Id de la persona en IMDB
# - `primaryName`: Nombre por el que es mas conocida la persona
# - `birthYear`: Año de nacimiento de la persona
# - `deathYear`: Año de fallecimiento de la persona
# - `primaryProfession`: Los tres roles que mas suele cumplir en los titulos
# - `knownForTitle`: Titulos por los que es conocido

# %%
imdb_name = pd.read_csv('data/name.basics.tsv', sep='\t')
imdb_name.head()
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                     primaryProfession                           knownForTitles
# 0        actor,miscellaneous,producer  tt0050419,tt0072308,tt0027125,tt0025164
# 1  actress,soundtrack,archive_footage  tt0037382,tt0075213,tt0038355,tt0117057
# 2   actress,music_department,producer  tt0057345,tt0049189,tt0056404,tt0054452
# 3       actor,writer,music_department  tt0072562,tt0077975,tt0080455,tt0078723
# 4               writer,director,actor  tt0050986,tt0069467,tt0050976,tt0083922

# %% [markdown]
# ## Creacion de Dataframe principal

# %% [markdown]
# ### Join con `imdb_basics`

# %%
df_main1 = dfprime.merge(imdb_basics, how='left', left_on='imdb_id', right_on='tconst')
df_main1.head()
# Out:
#          id                  title  year     imdb_id  tmdb_id      tconst  \
# 0  11001921  John Candy: I Like Me  2025  tt26683420  1492608  tt26683420
# 1   1882904   Maintenance Required  2025  tt33335602  1352755  tt33335602
# 2   1535445           Gladiator II  2024   tt9218128   558449   tt9218128
# 3   1532981             The Batman  2022   tt1877830   414906   tt1877830
# 4   1498670              Nosferatu  2024   tt5040012   426063   tt5040012
#
#   titleType           primaryTitle          originalTitle  isAdult startYear  \
# 0     movie  John Candy: I Like Me  John Candy: I Like Me      0.0      2025
# 1     movie   Maintenance Required   Maintenance Required      0.0      2025
# 2     movie           Gladiator II           Gladiator II      0.0      2024
# 3     movie             The Batman             The Batman      0.0      2022
# 4     movie              Nosferatu              Nosferatu      0.0      2024
#
#   endYear runtimeMinutes                        genres
# 0      \N            113  Biography,Comedy,Documentary
# 1      \N             \N                Comedy,Romance
# 2      \N            148        Action,Adventure,Drama
# 3      \N            176            Action,Crime,Drama
# 4      \N            132        Fantasy,Horror,Mystery

# %% [markdown]
# ### Join con `imdb_ratings`

# %%
df_main2 = df_main1.merge(imdb_ratings, how='left', left_on='imdb_id', right_on='tconst')
df_main2.head()
# Out:
#          id                  title  year     imdb_id  tmdb_id    tconst_x  \
# 0  11001921  John Candy: I Like Me  2025  tt26683420  1492608  tt26683420
# 1   1882904   Maintenance Required  2025  tt33335602  1352755  tt33335602
# 2   1535445           Gladiator II  2024   tt9218128   558449   tt9218128
# 3   1532981             The Batman  2022   tt1877830   414906   tt1877830
# 4   1498670              Nosferatu  2024   tt5040012   426063   tt5040012
#
#   titleType           primaryTitle          originalTitle  isAdult startYear  \
# 0     movie  John Candy: I Like Me  John Candy: I Like Me      0.0      2025
# 1     movie   Maintenance Required   Maintenance Required      0.0      2025
# 2     movie           Gladiator II           Gladiator II      0.0      2024
# 3     movie             The Batman             The Batman      0.0      2022
# 4     movie              Nosferatu              Nosferatu      0.0      2024
#
#   endYear runtimeMinutes                        genres    tconst_y  \
# 0      \N            113  Biography,Comedy,Documentary  tt26683420
# 1      \N             \N                Comedy,Romance         NaN
# 2      \N            148        Action,Adventure,Drama   tt9218128
# 3      \N            176            Action,Crime,Drama   tt1877830
# 4      \N            132        Fantasy,Horror,Mystery   tt5040012
#
#    averageRating  numVotes
# 0            7.5      78.0
# 1            NaN       NaN
# 2            6.5  272412.0
# 3            7.8  893476.0
# 4            7.2  232086.0

# %% [markdown]
# ### Join con `imdb_crew`

# %%
df_main3 = df_main2.merge(imdb_crew, how='left', left_on='imdb_id', right_on='tconst')
df_main3.head()
# Out:
#          id                  title  year     imdb_id  tmdb_id    tconst_x  \
# 0  11001921  John Candy: I Like Me  2025  tt26683420  1492608  tt26683420
# 1   1882904   Maintenance Required  2025  tt33335602  1352755  tt33335602
# 2   1535445           Gladiator II  2024   tt9218128   558449   tt9218128
# 3   1532981             The Batman  2022   tt1877830   414906   tt1877830
# 4   1498670              Nosferatu  2024   tt5040012   426063   tt5040012
#
#   titleType           primaryTitle          originalTitle  isAdult startYear  \
# 0     movie  John Candy: I Like Me  John Candy: I Like Me      0.0      2025
# 1     movie   Maintenance Required   Maintenance Required      0.0      2025
# 2     movie           Gladiator II           Gladiator II      0.0      2024
# 3     movie             The Batman             The Batman      0.0      2022
# 4     movie              Nosferatu              Nosferatu      0.0      2024
#
#   endYear runtimeMinutes                        genres    tconst_y  \
# 0      \N            113  Biography,Comedy,Documentary  tt26683420
# 1      \N             \N                Comedy,Romance         NaN
# 2      \N            148        Action,Adventure,Drama   tt9218128
# 3      \N            176            Action,Crime,Drama   tt1877830
# 4      \N            132        Fantasy,Horror,Mystery   tt5040012
#
#    averageRating  numVotes      tconst  directors  \
# 0            7.5      78.0  tt26683420  nm0004988
# 1            NaN       NaN  tt33335602  nm8919237
# 2            6.5  272412.0   tt9218128  nm0000631
# 3            7.8  893476.0   tt1877830  nm0716257
# 4            7.2  232086.0   tt5040012  nm3211470
#
#                                    writers
# 0                                       \N
# 1           nm12913021,nm2874428,nm8919237
# 2            nm0291905,nm0185976,nm0769227
# 3  nm0716257,nm0185976,nm0004170,nm0277730
# 4            nm3211470,nm0301961,nm0831290

# %% [markdown]
# ### Limpieza
# #### Eliminar columnas
# Eliminamos columnas con informacion repetida o irrelevante

# %%
df_main4 = df_main3[['id', 'imdb_id', 'title', 'primaryTitle', 'originalTitle', 'titleType', 'year', 'startYear', 
                     'isAdult', 'runtimeMinutes', 'genres', 'averageRating', 'numVotes', 'directors', 'writers']]
df_main4.head()
# Out:
#          id     imdb_id                  title           primaryTitle  \
# 0  11001921  tt26683420  John Candy: I Like Me  John Candy: I Like Me
# 1   1882904  tt33335602   Maintenance Required   Maintenance Required
# 2   1535445   tt9218128           Gladiator II           Gladiator II
# 3   1532981   tt1877830             The Batman             The Batman
# 4   1498670   tt5040012              Nosferatu              Nosferatu
#
#            originalTitle titleType  year startYear  isAdult runtimeMinutes  \
# 0  John Candy: I Like Me     movie  2025      2025      0.0            113
# 1   Maintenance Required     movie  2025      2025      0.0             \N
# 2           Gladiator II     movie  2024      2024      0.0            148
# 3             The Batman     movie  2022      2022      0.0            176
# 4              Nosferatu     movie  2024      2024      0.0            132
#
#                          genres  averageRating  numVotes  directors  \
# 0  Biography,Comedy,Documentary            7.5      78.0  nm0004988
# 1                Comedy,Romance            NaN       NaN  nm8919237
# 2        Action,Adventure,Drama            6.5  272412.0  nm0000631
# 3            Action,Crime,Drama            7.8  893476.0  nm0716257
# 4        Fantasy,Horror,Mystery            7.2  232086.0  nm3211470
#
#                                    writers
# 0                                       \N
# 1           nm12913021,nm2874428,nm8919237
# 2            nm0291905,nm0185976,nm0769227
# 3  nm0716257,nm0185976,nm0004170,nm0277730
# 4            nm3211470,nm0301961,nm0831290

# %% [markdown]
# #### Correcion valores nulos y tipos de columnas

# %%
df_main5 = df_main4.replace(['\\N', np.nan, None], pd.NA)

# %%
df_main5.dtypes
# Out:
# id                 int64
# imdb_id           object
# title             object
# primaryTitle      object
# originalTitle     object
# titleType         object
# year               int64
# startYear         object
# isAdult           object
# runtimeMinutes    object
# genres            object
# averageRating     object
# numVotes          object
# directors         object
# writers           object
# dtype: object

# %%
df_main5['titleType'] = df_main5['titleType'].astype('category')
df_main5['startYear'] = df_main5['startYear'].astype('Int64')
df_main5['isAdult'] = df_main5['isAdult'].astype('Int64')
df_main5['runtimeMinutes'] = df_main5['runtimeMinutes'].astype('Int64')
df_main5['averageRating'] = df_main5['averageRating'].astype('Float64')
df_main5['numVotes'] = df_main5['numVotes'].astype('Int64')

# %%
df_main5.head()
# Out:
#          id     imdb_id                  title           primaryTitle  \
# 0  11001921  tt26683420  John Candy: I Like Me  John Candy: I Like Me
# 1   1882904  tt33335602   Maintenance Required   Maintenance Required
# 2   1535445   tt9218128           Gladiator II           Gladiator II
# 3   1532981   tt1877830             The Batman             The Batman
# 4   1498670   tt5040012              Nosferatu              Nosferatu
#
#            originalTitle titleType  year  startYear  isAdult  runtimeMinutes  \
# 0  John Candy: I Like Me     movie  2025       2025        0             113
# 1   Maintenance Required     movie  2025       2025        0            <NA>
# 2           Gladiator II     movie  2024       2024        0             148
# 3             The Batman     movie  2022       2022        0             176
# 4              Nosferatu     movie  2024       2024        0             132
#
#                          genres  averageRating  numVotes  directors  \
# 0  Biography,Comedy,Documentary            7.5        78  nm0004988
# 1                Comedy,Romance           <NA>      <NA>  nm8919237
# 2        Action,Adventure,Drama            6.5    272412  nm0000631
# 3            Action,Crime,Drama            7.8    893476  nm0716257
# 4        Fantasy,Horror,Mystery            7.2    232086  nm3211470
#
#                                    writers
# 0                                     <NA>
# 1           nm12913021,nm2874428,nm8919237
# 2            nm0291905,nm0185976,nm0769227
# 3  nm0716257,nm0185976,nm0004170,nm0277730
# 4            nm3211470,nm0301961,nm0831290

# %%
for i in ['genres', 'directors', 'writers']:
    df_main5[i] = df_main5[i].apply(lambda x: str(x).split(',') if pd.notna(x) else [])

df_main5.head()
# Out:
#          id     imdb_id                  title           primaryTitle  \
# 0  11001921  tt26683420  John Candy: I Like Me  John Candy: I Like Me
# 1   1882904  tt33335602   Maintenance Required   Maintenance Required
# 2   1535445   tt9218128           Gladiator II           Gladiator II
# 3   1532981   tt1877830             The Batman             The Batman
# 4   1498670   tt5040012              Nosferatu              Nosferatu
#
#            originalTitle titleType  year  startYear  isAdult  runtimeMinutes  \
# 0  John Candy: I Like Me     movie  2025       2025        0             113
# 1   Maintenance Required     movie  2025       2025        0            <NA>
# 2           Gladiator II     movie  2024       2024        0             148
# 3             The Batman     movie  2022       2022        0             176
# 4              Nosferatu     movie  2024       2024        0             132
#
#                              genres  averageRating  numVotes    directors  \
# 0  [Biography, Comedy, Documentary]            7.5        78  [nm0004988]
# 1                 [Comedy, Romance]           <NA>      <NA>  [nm8919237]
# 2        [Action, Adventure, Drama]            6.5    272412  [nm0000631]
# 3            [Action, Crime, Drama]            7.8    893476  [nm0716257]
# 4        [Fantasy, Horror, Mystery]            7.2    232086  [nm3211470]
#
#                                         writers
# 0                                            []
# 1            [nm12913021, nm2874428, nm8919237]
# 2             [nm0291905, nm0185976, nm0769227]
# 3  [nm0716257, nm0185976, nm0004170, nm0277730]
# 4             [nm3211470, nm0301961, nm0831290]

# %% [markdown]
# #### Valores Na

# %%
resultados = {}
for i in df_main5.columns:
    resultados[i] = df_main5[i].isna().sum()
resultados
# Out:
# {'id': np.int64(0),
#  'imdb_id': np.int64(0),
#  'title': np.int64(0),
#  'primaryTitle': np.int64(4),
#  'originalTitle': np.int64(4),
#  'titleType': np.int64(4),
#  'year': np.int64(0),
#  'startYear': np.int64(5),
#  'isAdult': np.int64(4),
#  'runtimeMinutes': np.int64(44),
#  'genres': np.int64(0),
#  'averageRating': np.int64(9),
#  'numVotes': np.int64(9),
#  'directors': np.int64(0),
#  'writers': np.int64(0)}

# %%
df_main5[pd.isna(df_main5['runtimeMinutes'])]
# Out:
#             id     imdb_id                                              title  \
# 1      1882904  tt33335602                               Maintenance Required
# 18    11035495  tt38119836                                             SAQUON
# 537    1623475  tt11422728  Summer of Soul (...Or, When the Revolution Cou...
# 2526   1897521  tt33311244                                          Our Fault
# 2820   1169647   tt6793470                                      Forced Escape
# 2864   1872401  tt34754710                            Baban Baban Ban Vampire
# 3793   1700877  tt14832738                                   Solid Rock Trust
# 4256   1691266  tt13515772                                              Trust
# 4264   1653436  tt14176892                                          Untangled
# 4316   1634173   tt6239078                           100m Criminal Conviction
# 4415   4159571  tt21198470                                 The Boyfriend Trap
# 4427   1696677  tt15039816                                        Forbearance
# 4466   1606712   tt4546326                                  The Kingsbury Run
# 4499   1501450   tt8042234                                 Kalavani Mappillai
# 4585   1957425  tt26762470                                         First Love
# 4605   1637635  tt10926156                      A Comedy of Horrors: Volume 1
# 4809   1631456   tt7596520                                           Underdog
# 4965   1701875  tt15141146                               County Line: No Fear
# 5335   1644718  tt15203648                                A Wiseguy Christmas
# 5473   1894706  tt14623184                                Rudy! A Documusical
# 5495   1697138  tt23319678                                Matt Braunger: Doug
# 5510   1652087  tt12002148                                      Killer Whales
# 5678   1690573   tt8834606                              Bury Me When I'm Dead
# 5852   1965780  tt30985567                                        Get Close 2
# 6131   1913174   tt2242975                                        Blood Alley
# 6207   4148099  tt11015752                   PAW Patrol: Ready, Race, Rescue!
# 6209   1888945   tt2197561                                  Vengeance is Mine
# 6367   1698191  tt14117392                                     An Irish Angel
# 6449   1777834  tt30425668                                  The Dancing Queen
# 6454   1701829  tt15213572                               The Day You Found Me
# 6474   1545296   tt0492491                                          Songbirds
# 6582   1625502  tt13836494            Pinkfong & Baby Shark's Space Adventure
# 6880   1712366  tt26688393                               Tom Hanks: The Nomad
# 7207   1687655  tt11198146                                      Demon Fighter
# 7208   1686021  tt19063544                                  Banda de Rebeldes
# 7238   1628273  tt12145636                     Love You Right: An R&B Musical
# 7239   1627744  tt12938146                              China's New Silk Road
# 7295   1683482  tt13576768                                 The Sacrifice Zone
# 7301   1648317  tt13084594                                   After We're Over
# 7339   1697386  tt14211718                   King of Prison 2: The Prison War
# 7342   1640005  tt10669868                      Acting: The First Six Lessons
# 7353   1583606  tt10274176                                Most Dangerous Game
# 7354   1505201   tt4961326                                              Diwan
# 7358   1796155  tt27599817                           A Hipster in Rural Spain
#
#                           primaryTitle                     originalTitle  \
# 1                 Maintenance Required              Maintenance Required
# 18                              Saquon                            Saquon
# 537                               <NA>                              <NA>
# 2526                         Our Fault                     Culpa nuestra
# 2820                  Huroob Idhterari                  Huroob Idhterari
# 2864           Baban Baban Ban Vampire           Baban Baban Ban Vampire
# 3793                  Solid Rock Trust                  Solid Rock Trust
# 4256                             Trust                             Trust
# 4264                         Untangled                         Untangled
# 4316          100M Criminal Conviction          100M Criminal Conviction
# 4415                The Boyfriend Trap                The Boyfriend Trap
# 4427                       Forbearance                       Forbearance
# 4466                 The Kingsbury Run                 The Kingsbury Run
# 4499                Kalavani Mappillai                Kalavani Mappillai
# 4585                        First Love                             Si-ho
# 4605     A Comedy of Horrors, Volume 1     A Comedy of Horrors, Volume 1
# 4809                          Underdog                          Underdog
# 4965              County Line: No Fear              County Line: No Fear
# 5335               A Wiseguy Christmas               A Wiseguy Christmas
# 5473               Rudy! A Documusical               Rudy! A Documusical
# 5495               Matt Braunger: Doug               Matt Braunger: Doug
# 5510                     Killer Whales                     Killer Whales
# 5678             Bury Me When I'm Dead             Bury Me When I'm Dead
# 5852                       Get Close 2                       Get Close 2
# 6131                       Blood Alley                       Blood Alley
# 6207                              <NA>                              <NA>
# 6209                 Vengeance is Mine                 Vengeance is Mine
# 6367                    An Irish Angel                    An Irish Angel
# 6449                 The Dancing Queen                 The Dancing Queen
# 6454              The Day You Found Me              The Day You Found Me
# 6474                         Songbirds                         Songbirds
# 6582                              <NA>                              <NA>
# 6880              Tom Hanks: The Nomad              Tom Hanks: The Nomad
# 7207                     Demon Fighter                     Demon Fighter
# 7208                    Band of Rebels                    Band of Rebels
# 7238    Love You Right: An R&B Musical                    Love You Right
# 7239             China's New Silk Road             China's New Silk Road
# 7295  The Sacrifice Zone: The Activist  The Sacrifice Zone: The Activist
# 7301                  After We're Over                  After We're Over
# 7339  King of Prison 2: The Prison War    Beomteol 2: Jjeoneui Jeonjaeng
# 7342     Acting: The First Six Lessons     Acting: The First Six Lessons
# 7353               Most Dangerous Game               Most Dangerous Game
# 7354                             Diwan                             Diwan
# 7358                              <NA>                              <NA>
#
#       titleType  year  startYear  isAdult  runtimeMinutes  \
# 1         movie  2025       2025        0            <NA>
# 18        movie  2025       2025        0            <NA>
# 537         NaN  2021       <NA>     <NA>            <NA>
# 2526      movie  2025       2025        0            <NA>
# 2820      movie  2017       2017        0            <NA>
# 2864      movie  2025       2025        0            <NA>
# 3793      movie  2022       2022        0            <NA>
# 4256      movie  2022       2022        0            <NA>
# 4264      movie  2022       2022        0            <NA>
# 4316      movie  2021       2021        0            <NA>
# 4415      movie  2022       2022        0            <NA>
# 4427      movie  2022       2022        0            <NA>
# 4466      movie  2018       2018        0            <NA>
# 4499      movie  2018       2018        0            <NA>
# 4585      movie  2020       2020        0            <NA>
# 4605      movie  2021       2021        0            <NA>
# 4809      movie  2019       2019        0            <NA>
# 4965      movie  2022       2022        0            <NA>
# 5335      movie  2021       2021        0            <NA>
# 5473      movie  2022       2022        0            <NA>
# 5495      movie  2022       2022        0            <NA>
# 5510      movie  2022       2022        0            <NA>
# 5678      movie  2025       2025        0            <NA>
# 5852      movie  2024       2024        0            <NA>
# 6131  tvEpisode  2012       2012        0            <NA>
# 6207        NaN  2019       <NA>     <NA>            <NA>
# 6209  tvEpisode  2012       2012        0            <NA>
# 6367      movie  2022       2024        0            <NA>
# 6449      movie  2024       2024        0            <NA>
# 6454      movie  2022       2022        0            <NA>
# 6474      movie  2007       2005        0            <NA>
# 6582        NaN  2019       <NA>     <NA>            <NA>
# 6880      movie  2023       2023        0            <NA>
# 7207      movie  2022       2022        0            <NA>
# 7208      movie  2022       2022        0            <NA>
# 7238      movie  2021       2021        0            <NA>
# 7239      movie  2019       2019        0            <NA>
# 7295      movie  2022       2022        0            <NA>
# 7301      movie  2021       2021        0            <NA>
# 7339      movie  2021       2021        0            <NA>
# 7342      movie  2020       2021        0            <NA>
# 7353      movie  2020       <NA>        0            <NA>
# 7354      movie  2003       2003        0            <NA>
# 7358        NaN  2024       <NA>     <NA>            <NA>
#
#                            genres  averageRating  numVotes  \
# 1               [Comedy, Romance]           <NA>      <NA>
# 18                  [Documentary]           <NA>      <NA>
# 537                            []           <NA>      <NA>
# 2526                    [Romance]           <NA>      <NA>
# 2820      [Action, Comedy, Drama]            6.0      1850
# 2864   [Comedy, Fantasy, Romance]            5.6        18
# 3793            [Drama, Thriller]            6.2       110
# 4256                      [Drama]            7.0       111
# 4264             [Drama, Romance]            4.4        58
# 4316                      [Crime]            5.4        86
# 4415                    [Romance]            6.9        76
# 4427                      [Drama]            7.4        24
# 4466     [Crime, Drama, Thriller]            5.0        35
# 4499            [Comedy, Romance]            5.0        56
# 4585                    [Romance]            5.6       115
# 4605             [Comedy, Horror]            5.8       168
# 4809               [Drama, Sport]            6.5        88
# 4965                     [Action]            6.5       233
# 5335             [Action, Comedy]            7.4       307
# 5473                [Documentary]            7.2        35
# 5495                     [Comedy]            6.9        47
# 5510                     [Comedy]            4.7        40
# 5678  [Horror, Mystery, Thriller]            4.4        59
# 5852   [Action, Adventure, Crime]            5.7        47
# 6131       [Action, Crime, Drama]            5.3       208
# 6207                           []           <NA>      <NA>
# 6209       [Action, Crime, Drama]            5.9       159
# 6367                      [Drama]            5.9       149
# 6449                    [Romance]            4.6        24
# 6454                      [Drama]            6.6       109
# 6474       [Documentary, Musical]            7.4        60
# 6582                           []           <NA>      <NA>
# 6880                  [Biography]            4.4       250
# 7207                     [Horror]            6.3        68
# 7208             [Drama, Western]            3.7        87
# 7238    [Drama, Musical, Romance]            7.2        88
# 7239                [Documentary]            6.9       100
# 7295                   [Thriller]            5.4        51
# 7301                           []            8.5        50
# 7339                     [Action]            3.8         6
# 7342                      [Drama]            7.4        14
# 7353                     [Comedy]           <NA>      <NA>
# 7354                     [Action]            5.1        45
# 7358                           []           <NA>      <NA>
#
#                                          directors  \
# 1                                      [nm8919237]
# 18                                    [nm11941708]
# 537                                             []
# 2526                                   [nm0328126]
# 2820                                   [nm5394449]
# 2864                                  [nm11008729]
# 3793                                   [nm3546744]
# 4256                                   [nm4509732]
# 4264                                   [nm6963836]
# 4316                                   [nm8576884]
# 4415                                   [nm0583659]
# 4427                                   [nm2526715]
# 4466                                   [nm3225951]
# 4499                       [nm9647741, nm11262032]
# 4585                                  [nm10410528]
# 4605  [nm1290135, nm1370480, nm1912178, nm0785854]
# 4809                                   [nm2758338]
# 4965                                   [nm3636519]
# 5335                                   [nm0368693]
# 5473                                   [nm1160206]
# 5495                                   [nm2286712]
# 5510                                   [nm8646351]
# 5678                                   [nm2718960]
# 5852                                   [nm5479101]
# 6131                                   [nm1074029]
# 6207                                            []
# 6209                                   [nm0915394]
# 6367                                   [nm1274199]
# 6449                                  [nm12256037]
# 6454                                   [nm4740006]
# 6474                                   [nm0384089]
# 6582                                            []
# 6880                                  [nm15527370]
# 7207                                   [nm8922641]
# 7208                                   [nm2483722]
# 7238                                   [nm8523744]
# 7239                                  [nm11832996]
# 7295                                   [nm0605513]
# 7301                                   [nm3726267]
# 7339                                  [nm11737113]
# 7342                                   [nm0108733]
# 7353                                            []
# 7354                                   [nm1870310]
# 7358                                            []
#
#                                   writers
# 1      [nm12913021, nm2874428, nm8919237]
# 18                                     []
# 537                                    []
# 2526   [nm3399103, nm0328126, nm13982803]
# 2820                         [nm10080143]
# 2864              [nm1883488, nm16768805]
# 3793                          [nm3546744]
# 4256               [nm4509732, nm4578941]
# 4264  [nm10035732, nm11834397, nm8355768]
# 4316                          [nm8148131]
# 4415                          [nm2433904]
# 4427                          [nm7391561]
# 4466               [nm3594775, nm3225951]
# 4499                                   []
# 4585                                   []
# 4605                                   []
# 4809                          [nm2758338]
# 4965                          [nm1156122]
# 5335                          [nm1191714]
# 5473                          [nm1160206]
# 5495                                   []
# 5510                          [nm7516394]
# 5678                          [nm2718960]
# 5852                          [nm4636486]
# 6131               [nm0064174, nm0915394]
# 6207                                   []
# 6209                          [nm0915394]
# 6367                          [nm1274199]
# 6449                          [nm1102012]
# 6454                          [nm3929888]
# 6474                                   []
# 6582                                   []
# 6880                          [nm9592365]
# 7207                          [nm8922641]
# 7208                          [nm2483722]
# 7238               [nm8523744, nm7510010]
# 7239                                   []
# 7295                          [nm0605513]
# 7301                          [nm3726267]
# 7339                         [nm11737113]
# 7342               [nm0092915, nm0108733]
# 7353                          [nm4199289]
# 7354                                   []
# 7358                                   []

# %%
df_main5[pd.isna(df_main5['averageRating'])]
# Out:
#             id     imdb_id                                              title  \
# 1      1882904  tt33335602                               Maintenance Required
# 18    11035495  tt38119836                                             SAQUON
# 36     1684871  tt18392014                                         Play Dirty
# 537    1623475  tt11422728  Summer of Soul (...Or, When the Revolution Cou...
# 2526   1897521  tt33311244                                          Our Fault
# 6207   4148099  tt11015752                   PAW Patrol: Ready, Race, Rescue!
# 6582   1625502  tt13836494            Pinkfong & Baby Shark's Space Adventure
# 7353   1583606  tt10274176                                Most Dangerous Game
# 7358   1796155  tt27599817                           A Hipster in Rural Spain
#
#               primaryTitle         originalTitle titleType  year  startYear  \
# 1     Maintenance Required  Maintenance Required     movie  2025       2025
# 18                  Saquon                Saquon     movie  2025       2025
# 36              Play Dirty            Play Dirty     movie  2025       2025
# 537                   <NA>                  <NA>       NaN  2021       <NA>
# 2526             Our Fault         Culpa nuestra     movie  2025       2025
# 6207                  <NA>                  <NA>       NaN  2019       <NA>
# 6582                  <NA>                  <NA>       NaN  2019       <NA>
# 7353   Most Dangerous Game   Most Dangerous Game     movie  2020       <NA>
# 7358                  <NA>                  <NA>       NaN  2024       <NA>
#
#       isAdult  runtimeMinutes             genres  averageRating  numVotes  \
# 1           0            <NA>  [Comedy, Romance]           <NA>      <NA>
# 18          0            <NA>      [Documentary]           <NA>      <NA>
# 36          0             125     [Crime, Drama]           <NA>      <NA>
# 537      <NA>            <NA>                 []           <NA>      <NA>
# 2526        0            <NA>          [Romance]           <NA>      <NA>
# 6207     <NA>            <NA>                 []           <NA>      <NA>
# 6582     <NA>            <NA>                 []           <NA>      <NA>
# 7353        0            <NA>           [Comedy]           <NA>      <NA>
# 7358     <NA>            <NA>                 []           <NA>      <NA>
#
#          directors                                       writers
# 1      [nm8919237]            [nm12913021, nm2874428, nm8919237]
# 18    [nm11941708]                                            []
# 36     [nm0000948]  [nm0922799, nm0000948, nm3143168, nm0046524]
# 537             []                                            []
# 2526   [nm0328126]            [nm3399103, nm0328126, nm13982803]
# 6207            []                                            []
# 6582            []                                            []
# 7353            []                                   [nm4199289]
# 7358            []                                            []

# %% [markdown]
# #### Duplicados

# %%
df_main5.duplicated('imdb_id').sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Analisis de columnas

# %%
df_main5.describe()
# Out:
#                  id         year   startYear  isAdult  runtimeMinutes  \
# count  7.387000e+03  7387.000000      7382.0   7383.0          7343.0
# mean   1.286783e+06  2008.658996  2008.55527      0.0      102.200327
# std    5.810034e+05    18.162548   18.136997      0.0       21.347217
# min    1.240000e+02  1916.000000      1916.0      0.0            40.0
# 25%    1.189871e+06  2005.000000      2005.0      0.0            89.0
# 50%    1.399781e+06  2016.000000      2016.0      0.0            97.0
# 75%    1.608651e+06  2020.000000      2020.0      0.0           110.0
# max    1.103550e+07  2025.000000      2025.0      0.0           357.0
#
#        averageRating      numVotes
# count         7378.0        7378.0
# mean        5.821618   17435.83505
# std          1.26408  68580.522345
# min              1.4           6.0
# 25%              5.1        929.25
# 50%              6.0        2911.0
# 75%              6.7       9149.25
# max              9.6     2367400.0

# %%
dfmain = df_main5

# %%
dfmain.to_csv('data/imdb_prime.csv')

# %% [markdown]
# ## Creacion Dataframe personas

# %% [markdown]
# ### Join con `imdb_principals`

# %%
df_personas1 = dfmain.merge(imdb_principals, how='left', left_on='imdb_id', right_on='tconst')
df_personas1.head()
# Out:
#          id     imdb_id                  title           primaryTitle  \
# 0  11001921  tt26683420  John Candy: I Like Me  John Candy: I Like Me
# 1  11001921  tt26683420  John Candy: I Like Me  John Candy: I Like Me
# 2  11001921  tt26683420  John Candy: I Like Me  John Candy: I Like Me
# 3  11001921  tt26683420  John Candy: I Like Me  John Candy: I Like Me
# 4  11001921  tt26683420  John Candy: I Like Me  John Candy: I Like Me
#
#            originalTitle titleType  year  startYear  isAdult  runtimeMinutes  \
# 0  John Candy: I Like Me     movie  2025       2025        0             113
# 1  John Candy: I Like Me     movie  2025       2025        0             113
# 2  John Candy: I Like Me     movie  2025       2025        0             113
# 3  John Candy: I Like Me     movie  2025       2025        0             113
# 4  John Candy: I Like Me     movie  2025       2025        0             113
#
#    ... averageRating  numVotes    directors writers      tconst ordering  \
# 0  ...           7.5        78  [nm0004988]      []  tt26683420      1.0
# 1  ...           7.5        78  [nm0004988]      []  tt26683420      2.0
# 2  ...           7.5        78  [nm0004988]      []  tt26683420      3.0
# 3  ...           7.5        78  [nm0004988]      []  tt26683420      4.0
# 4  ...           7.5        78  [nm0004988]      []  tt26683420      5.0
#
#       nconst         category job characters
# 0  nm0000158            actor  \N         \N
# 1  nm0001006  archive_footage  \N   ["Self"]
# 2  nm0000195             self  \N   ["Self"]
# 3  nm0000188            actor  \N         \N
# 4  nm0000316             self  \N   ["Self"]
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Eliminar columnas

# %%
df_personas2 = df_personas1[['id', 'imdb_id', 'title', 'nconst', 'ordering', 'category', 'job', 'characters', 'primaryTitle',
                             'originalTitle', 'titleType', 'year', 'startYear', 'isAdult', 'runtimeMinutes', 'genres', 'averageRating',
                             'numVotes', 'directors', 'writers']]
df_personas2.head()
# Out:
#          id     imdb_id                  title     nconst  ordering  \
# 0  11001921  tt26683420  John Candy: I Like Me  nm0000158       1.0
# 1  11001921  tt26683420  John Candy: I Like Me  nm0001006       2.0
# 2  11001921  tt26683420  John Candy: I Like Me  nm0000195       3.0
# 3  11001921  tt26683420  John Candy: I Like Me  nm0000188       4.0
# 4  11001921  tt26683420  John Candy: I Like Me  nm0000316       5.0
#
#           category job characters           primaryTitle  \
# 0            actor  \N         \N  John Candy: I Like Me
# 1  archive_footage  \N   ["Self"]  John Candy: I Like Me
# 2             self  \N   ["Self"]  John Candy: I Like Me
# 3            actor  \N         \N  John Candy: I Like Me
# 4             self  \N   ["Self"]  John Candy: I Like Me
#
#            originalTitle titleType  year  startYear  isAdult  runtimeMinutes  \
# 0  John Candy: I Like Me     movie  2025       2025        0             113
# 1  John Candy: I Like Me     movie  2025       2025        0             113
# 2  John Candy: I Like Me     movie  2025       2025        0             113
# 3  John Candy: I Like Me     movie  2025       2025        0             113
# 4  John Candy: I Like Me     movie  2025       2025        0             113
#
#                              genres  averageRating  numVotes    directors  \
# 0  [Biography, Comedy, Documentary]            7.5        78  [nm0004988]
# 1  [Biography, Comedy, Documentary]            7.5        78  [nm0004988]
# 2  [Biography, Comedy, Documentary]            7.5        78  [nm0004988]
# 3  [Biography, Comedy, Documentary]            7.5        78  [nm0004988]
# 4  [Biography, Comedy, Documentary]            7.5        78  [nm0004988]
#
#   writers
# 0      []
# 1      []
# 2      []
# 3      []
# 4      []

# %% [markdown]
# ### Arreglar valores nulos y columnas

# %%
df_personas3 = df_personas2.replace(['\\N', np.nan, None], pd.NA)
df_personas3.head()
# Out:
#          id     imdb_id                  title     nconst ordering  \
# 0  11001921  tt26683420  John Candy: I Like Me  nm0000158      1.0
# 1  11001921  tt26683420  John Candy: I Like Me  nm0001006      2.0
# 2  11001921  tt26683420  John Candy: I Like Me  nm0000195      3.0
# 3  11001921  tt26683420  John Candy: I Like Me  nm0000188      4.0
# 4  11001921  tt26683420  John Candy: I Like Me  nm0000316      5.0
#
#           category   job characters           primaryTitle  \
# 0            actor  <NA>       <NA>  John Candy: I Like Me
# 1  archive_footage  <NA>   ["Self"]  John Candy: I Like Me
# 2             self  <NA>   ["Self"]  John Candy: I Like Me
# 3            actor  <NA>       <NA>  John Candy: I Like Me
# 4             self  <NA>   ["Self"]  John Candy: I Like Me
#
#            originalTitle titleType  year  startYear  isAdult  runtimeMinutes  \
# 0  John Candy: I Like Me     movie  2025       2025        0             113
# 1  John Candy: I Like Me     movie  2025       2025        0             113
# 2  John Candy: I Like Me     movie  2025       2025        0             113
# 3  John Candy: I Like Me     movie  2025       2025        0             113
# 4  John Candy: I Like Me     movie  2025       2025        0             113
#
#                              genres  averageRating  numVotes    directors  \
# 0  [Biography, Comedy, Documentary]            7.5        78  [nm0004988]
# 1  [Biography, Comedy, Documentary]            7.5        78  [nm0004988]
# 2  [Biography, Comedy, Documentary]            7.5        78  [nm0004988]
# 3  [Biography, Comedy, Documentary]            7.5        78  [nm0004988]
# 4  [Biography, Comedy, Documentary]            7.5        78  [nm0004988]
#
#   writers
# 0      []
# 1      []
# 2      []
# 3      []
# 4      []

# %%
df_personas3.dtypes
# Out:
# id                   int64
# imdb_id             object
# title               object
# nconst              object
# ordering            object
# category            object
# job                 object
# characters          object
# primaryTitle        object
# originalTitle       object
# titleType         category
# year                 int64
# startYear            Int64
# isAdult              Int64
# runtimeMinutes       Int64
# genres              object
# averageRating      Float64
# numVotes             Int64
# directors           object
# writers             object
# dtype: object

# %%
df_personas3['ordering'] = df_personas3['ordering'].astype('Int64')
df_personas3['category'] = df_personas3['category'].astype('category')

# %% [markdown]
# ### Valores nulos

# %%
resultados = {}
for i in df_personas3.columns:
    resultados[i] = df_personas3[i].isna().sum()
resultados
# Out:
# {'id': np.int64(0),
#  'imdb_id': np.int64(0),
#  'title': np.int64(0),
#  'nconst': np.int64(4),
#  'ordering': np.int64(4),
#  'category': np.int64(4),
#  'job': np.int64(110882),
#  'characters': np.int64(75591),
#  'primaryTitle': np.int64(4),
#  'originalTitle': np.int64(4),
#  'titleType': np.int64(4),
#  'year': np.int64(0),
#  'startYear': np.int64(10),
#  'isAdult': np.int64(4),
#  'runtimeMinutes': np.int64(607),
#  'genres': np.int64(0),
#  'averageRating': np.int64(81),
#  'numVotes': np.int64(81),
#  'directors': np.int64(0),
#  'writers': np.int64(0)}

# %%
dfpersonas = df_personas3

# %%
dfpersonas.to_csv('data/personas_prime.csv')
