# %%
import pandas as pd

# %%
df= pd.read_csv('data/imdb_prime.csv')

# %%
df['genres'].unique()
# Out:
# array(["['Biography', 'Comedy', 'Documentary']", "['Comedy', 'Romance']",
#        "['Action', 'Adventure', 'Drama']", "['Action', 'Crime', 'Drama']",
#        "['Fantasy', 'Horror', 'Mystery']", "['Drama', 'Thriller']",
#        "['Biography', 'Fantasy', 'Music']",
#        "['Fantasy', 'Musical', 'Romance']",
#        "['Action', 'Adventure', 'Comedy']", "['Action', 'Adventure']",
#        "['Action', 'Adventure', 'Horror']",
#        "['Action', 'Comedy', 'Thriller']",
#        "['Action', 'Adventure', 'Animation']",
#        "['Comedy', 'Crime', 'Drama']",
#        "['Action', 'Adventure', 'Thriller']",
#        "['Action', 'Comedy', 'Crime']", "['Documentary']",
#        "['Drama', 'Mystery', 'Romance']", "['Action', 'Thriller']",
#        "['Action', 'Comedy', 'Drama']", "['Action', 'Crime', 'Thriller']",
#        "['Comedy', 'Drama']", "['Biography', 'Comedy', 'Drama']",
#        "['Comedy', 'Drama', 'Romance']", "['Horror']", "['Comedy']",
# ...
