# %% [markdown]
# # Creacion de DataFrames de Hulu

# %% [markdown]
# ## Lecturas archivos

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### api_hulu
# Informacion de las peliculas dada por la API. Sus columnas son:
# Las columnas nos entregan los siguientes datos:
# - `id`: Identificador de la pelicula en la API
# - `title`: Nombre de la pelicula
# - `year`: Año de estreno de la pelicula
# - `imdb_id`: Identificador de la pelicula en IMDB
# - `tmdb_id`: Identificador de la pelicula en TMDB
# - `tmdb_type`: Tipo del titulo en TMDB
# - `type`: Tipo del titulo en la API

# %%
dfhulu = pd.read_csv('../data/api_hulu.csv')
dfhulu.head()
# Out:
#         id                        title  year     imdb_id  tmdb_id
# 0  1874486  Predator: Killer of Killers  2025  tt36463894  1376434
# 1  1615420                 Bullet Train  2022  tt12593682   718930
# 2  1583908                     The Menu  2022   tt9764362   593643
# 3  1515072                    Uncharted  2022   tt1464335   335787
# 4  1650358                    Barbarian  2022  tt15791034   913290

# %% [markdown]
# ### imdb_basics
# Informacion basica de cada titulo en IMDB. Sus columnas son:
# - `tconst`: Id del titulo en IMDB
# - `titleType`: Tipo del titulo
# - `primaryTitle`: Nombre mas comun del titulo
# - `originalTitle`: Nombre original del titulo
# - `isAdult`: Bool que indica si es para adultos o no
# - `startYear`: Año de salida, en series es el año de comienzo de la serie
# - `endYear`: Año de fin de la serie (No muy util ya que solo trabajaremos con peliculas)
# - `runtimeMinutes`: Duracion del titulo en minutos
# - `genres`: Lista de generos del titulo

# %%
imdb_basics = pd.read_csv('../data/title.basics.tsv', sep='\t')
imdb_basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short            Poor Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#    isAdult startYear endYear runtimeMinutes                    genres
# 0        0      1894      \N              1         Documentary,Short
# 1        0      1892      \N              5           Animation,Short
# 2        0      1892      \N              5  Animation,Comedy,Romance
# 3        0      1892      \N             12           Animation,Short
# 4        0      1893      \N              1                     Short

# %% [markdown]
# ### imdb_ratings
# Rating de cada pelicula en IMDB. Sus columnas son:
# - `tconst`: Id de IMDB
# - `averageRating`: Puntaje promedio dado por los votos
# - `numVotes`: Cantidad de votos

# %%
imdb_ratings = pd.read_csv('../data/title.ratings.tsv', sep='\t')
imdb_ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2178
# 1  tt0000002            5.5       299
# 2  tt0000003            6.4      2243
# 3  tt0000004            5.2       193
# 4  tt0000005            6.2      2986

# %% [markdown]
# ### imdb_principals
# Trabajadores involucrados en cada titulo de IMDB (directores, productores, actores, etc.). Sus columnas son:
# - `tconst`: Id del titulo en IMDB
# - `ordering`: Id para enumerar a los trabajadores por titulo
# - `nconst`: Id de persona en IMDB
# - `category`: Categoria del rol que cumplio en el titulo
# - `job`: Trabajo que tenia en el titulo
# - `characters`: En caso de ser actor, muestra los nombres de los personajes que interpreta

# %%
imdb_principals = pd.read_csv('../data/title.principals.tsv', sep='\t')
imdb_principals.head()
# Out:
#       tconst  ordering     nconst         category                      job  \
# 0  tt0000001         1  nm1588970             self                       \N
# 1  tt0000001         2  nm0005690         director                       \N
# 2  tt0000001         3  nm0005690         producer                 producer
# 3  tt0000001         4  nm0374658  cinematographer  director of photography
# 4  tt0000002         1  nm0721526         director                       \N
#
#   characters
# 0   ["Self"]
# 1         \N
# 2         \N
# 3         \N
# 4         \N

# %% [markdown]
# ### imdb_crew
# Directores y escritores de cada titulo en IMDB. Sus columnas son:
# - `tconst`: Id del titulo en IMDB
# - `directors`: Id de persona del director en IMDB
# - `writers`: Id de persona de los escritores en IMDB

# %%
imdb_crew = pd.read_csv('../data/title.crew.tsv', sep='\t')
imdb_crew.head()
# Out:
#       tconst  directors    writers
# 0  tt0000001  nm0005690         \N
# 1  tt0000002  nm0721526         \N
# 2  tt0000003  nm0721526  nm0721526
# 3  tt0000004  nm0721526         \N
# 4  tt0000005  nm0005690         \N

# %% [markdown]
# ### imdb_name
# Este Dataframe contiene informacion de cada persona relacionada a titulos dentro de IMDB. Sus columnas son:
# - `nconst`: Id de la persona en IMDB
# - `primaryName`: Nombre por el que es mas conocida la persona
# - `birthYear`: Año de nacimiento de la persona
# - `deathYear`: Año de fallecimiento de la persona
# - `primaryProfession`: Los tres roles que mas suele cumplir en los titulos
# - `knownForTitle`: Titulos por los que es conocido

# %%
imdb_name = pd.read_csv('../data/name.basics.tsv', sep='\t')
imdb_name.head()
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                     primaryProfession                           knownForTitles
# 0        actor,miscellaneous,producer  tt0050419,tt0072308,tt0027125,tt0025164
# 1  actress,soundtrack,archive_footage  tt0037382,tt0075213,tt0038355,tt0117057
# 2   actress,music_department,producer  tt0057345,tt0049189,tt0056404,tt0054452
# 3       actor,writer,music_department  tt0072562,tt0077975,tt0080455,tt0078723
# 4               writer,director,actor  tt0050986,tt0069467,tt0050976,tt0083922

# %% [markdown]
# ## Creacion de Dataframe principal

# %% [markdown]
# ### Join con `imdb_basics`

# %%
df_main1 = dfhulu.merge(imdb_basics, how='left', left_on='imdb_id', right_on='tconst')
df_main1.head()
# Out:
#         id                        title  year     imdb_id  tmdb_id  \
# 0  1874486  Predator: Killer of Killers  2025  tt36463894  1376434
# 1  1615420                 Bullet Train  2022  tt12593682   718930
# 2  1583908                     The Menu  2022   tt9764362   593643
# 3  1515072                    Uncharted  2022   tt1464335   335787
# 4  1650358                    Barbarian  2022  tt15791034   913290
#
#        tconst titleType                 primaryTitle  \
# 0  tt36463894     movie  Predator: Killer of Killers
# 1  tt12593682     movie                 Bullet Train
# 2   tt9764362     movie                     The Menu
# 3   tt1464335     movie                    Uncharted
# 4  tt15791034     movie                    Barbarian
#
#                  originalTitle  isAdult startYear endYear runtimeMinutes  \
# 0  Predator: Killer of Killers      0.0      2025      \N             85
# 1                 Bullet Train      0.0      2022      \N            127
# 2                     The Menu      0.0      2022      \N            107
# 3                    Uncharted      0.0      2022      \N            116
# 4                    Barbarian      0.0      2022      \N            102
#
#                        genres
# 0  Action,Adventure,Animation
# 1      Action,Comedy,Thriller
# 2      Comedy,Horror,Thriller
# 3            Action,Adventure
# 4     Horror,Mystery,Thriller

# %% [markdown]
# ### Join con `imdb_ratings`

# %%
df_main2 = df_main1.merge(imdb_ratings, how='left', left_on='imdb_id', right_on='tconst')
df_main2.head()
# Out:
#         id                        title  year     imdb_id  tmdb_id  \
# 0  1874486  Predator: Killer of Killers  2025  tt36463894  1376434
# 1  1615420                 Bullet Train  2022  tt12593682   718930
# 2  1583908                     The Menu  2022   tt9764362   593643
# 3  1515072                    Uncharted  2022   tt1464335   335787
# 4  1650358                    Barbarian  2022  tt15791034   913290
#
#      tconst_x titleType                 primaryTitle  \
# 0  tt36463894     movie  Predator: Killer of Killers
# 1  tt12593682     movie                 Bullet Train
# 2   tt9764362     movie                     The Menu
# 3   tt1464335     movie                    Uncharted
# 4  tt15791034     movie                    Barbarian
#
#                  originalTitle  isAdult startYear endYear runtimeMinutes  \
# 0  Predator: Killer of Killers      0.0      2025      \N             85
# 1                 Bullet Train      0.0      2022      \N            127
# 2                     The Menu      0.0      2022      \N            107
# 3                    Uncharted      0.0      2022      \N            116
# 4                    Barbarian      0.0      2022      \N            102
#
#                        genres    tconst_y  averageRating  numVotes
# 0  Action,Adventure,Animation  tt36463894            7.5   44742.0
# 1      Action,Comedy,Thriller  tt12593682            7.3  506862.0
# 2      Comedy,Horror,Thriller   tt9764362            7.2  469715.0
# 3            Action,Adventure   tt1464335            6.3  288938.0
# 4     Horror,Mystery,Thriller  tt15791034            7.0  237987.0

# %% [markdown]
# ### Join con `imdb_crew`

# %%
df_main3 = df_main2.merge(imdb_crew, how='left', left_on='imdb_id', right_on='tconst')
df_main3.head()
# Out:
#         id                        title  year     imdb_id  tmdb_id  \
# 0  1874486  Predator: Killer of Killers  2025  tt36463894  1376434
# 1  1615420                 Bullet Train  2022  tt12593682   718930
# 2  1583908                     The Menu  2022   tt9764362   593643
# 3  1515072                    Uncharted  2022   tt1464335   335787
# 4  1650358                    Barbarian  2022  tt15791034   913290
#
#      tconst_x titleType                 primaryTitle  \
# 0  tt36463894     movie  Predator: Killer of Killers
# 1  tt12593682     movie                 Bullet Train
# 2   tt9764362     movie                     The Menu
# 3   tt1464335     movie                    Uncharted
# 4  tt15791034     movie                    Barbarian
#
#                  originalTitle  isAdult startYear endYear runtimeMinutes  \
# 0  Predator: Killer of Killers      0.0      2025      \N             85
# 1                 Bullet Train      0.0      2022      \N            127
# 2                     The Menu      0.0      2022      \N            107
# 3                    Uncharted      0.0      2022      \N            116
# 4                    Barbarian      0.0      2022      \N            102
#
#                        genres    tconst_y  averageRating  numVotes  \
# 0  Action,Adventure,Animation  tt36463894            7.5   44742.0
# 1      Action,Comedy,Thriller  tt12593682            7.3  506862.0
# 2      Comedy,Horror,Thriller   tt9764362            7.2  469715.0
# 3            Action,Adventure   tt1464335            6.3  288938.0
# 4     Horror,Mystery,Thriller  tt15791034            7.0  237987.0
#
#        tconst            directors  \
# 0  tt36463894  nm0870469,nm1945519
# 1  tt12593682            nm0500610
# 2   tt9764362            nm0617042
# 3   tt1464335            nm0281508
# 4  tt15791034            nm1199107
#
#                                              writers
# 0            nm3026436,nm0870469,nm0859029,nm0859049
# 1                                nm5599654,nm2157655
# 2                                nm2219721,nm4301557
# 3  nm1988994,nm1436466,nm0391344,nm2616125,nm4731086
# 4                                          nm1199107

# %% [markdown]
# ### Limpieza
# #### Eliminar columnas
# Eliminamos columnas con informacion repetida o irrelevante

# %%
df_main4 = df_main3[['id', 'imdb_id', 'title', 'primaryTitle', 'originalTitle', 'titleType', 'year', 'startYear', 
                     'isAdult', 'runtimeMinutes', 'genres', 'averageRating', 'numVotes', 'directors', 'writers']]
df_main4.head()
# Out:
#         id     imdb_id                        title  \
# 0  1874486  tt36463894  Predator: Killer of Killers
# 1  1615420  tt12593682                 Bullet Train
# 2  1583908   tt9764362                     The Menu
# 3  1515072   tt1464335                    Uncharted
# 4  1650358  tt15791034                    Barbarian
#
#                   primaryTitle                originalTitle titleType  year  \
# 0  Predator: Killer of Killers  Predator: Killer of Killers     movie  2025
# 1                 Bullet Train                 Bullet Train     movie  2022
# 2                     The Menu                     The Menu     movie  2022
# 3                    Uncharted                    Uncharted     movie  2022
# 4                    Barbarian                    Barbarian     movie  2022
#
#   startYear  isAdult runtimeMinutes                      genres  \
# 0      2025      0.0             85  Action,Adventure,Animation
# 1      2022      0.0            127      Action,Comedy,Thriller
# 2      2022      0.0            107      Comedy,Horror,Thriller
# 3      2022      0.0            116            Action,Adventure
# 4      2022      0.0            102     Horror,Mystery,Thriller
#
#    averageRating  numVotes            directors  \
# 0            7.5   44742.0  nm0870469,nm1945519
# 1            7.3  506862.0            nm0500610
# 2            7.2  469715.0            nm0617042
# 3            6.3  288938.0            nm0281508
# 4            7.0  237987.0            nm1199107
#
#                                              writers
# 0            nm3026436,nm0870469,nm0859029,nm0859049
# 1                                nm5599654,nm2157655
# 2                                nm2219721,nm4301557
# 3  nm1988994,nm1436466,nm0391344,nm2616125,nm4731086
# 4                                          nm1199107

# %% [markdown]
# #### Correcion valores nulos y tipos de columnas

# %%
df_main5 = df_main4.replace(['\\N', np.nan, None], pd.NA)

# %%
df_main5.dtypes
# Out:
# id                 int64
# imdb_id           object
# title             object
# primaryTitle      object
# originalTitle     object
# titleType         object
# year               int64
# startYear         object
# isAdult           object
# runtimeMinutes    object
# genres            object
# averageRating     object
# numVotes          object
# directors         object
# writers           object
# dtype: object

# %%
df_main5['titleType'] = df_main5['titleType'].astype('category')
df_main5['startYear'] = df_main5['startYear'].astype('Int64')
df_main5['isAdult'] = df_main5['isAdult'].astype('Int64')
df_main5['runtimeMinutes'] = df_main5['runtimeMinutes'].astype('Int64')
df_main5['averageRating'] = df_main5['averageRating'].astype('Float64')
df_main5['numVotes'] = df_main5['numVotes'].astype('Int64')

# %%
df_main5.head()
# Out:
#         id     imdb_id                        title  \
# 0  1874486  tt36463894  Predator: Killer of Killers
# 1  1615420  tt12593682                 Bullet Train
# 2  1583908   tt9764362                     The Menu
# 3  1515072   tt1464335                    Uncharted
# 4  1650358  tt15791034                    Barbarian
#
#                   primaryTitle                originalTitle titleType  year  \
# 0  Predator: Killer of Killers  Predator: Killer of Killers     movie  2025
# 1                 Bullet Train                 Bullet Train     movie  2022
# 2                     The Menu                     The Menu     movie  2022
# 3                    Uncharted                    Uncharted     movie  2022
# 4                    Barbarian                    Barbarian     movie  2022
#
#    startYear  isAdult  runtimeMinutes                      genres  \
# 0       2025        0              85  Action,Adventure,Animation
# 1       2022        0             127      Action,Comedy,Thriller
# 2       2022        0             107      Comedy,Horror,Thriller
# 3       2022        0             116            Action,Adventure
# 4       2022        0             102     Horror,Mystery,Thriller
#
#    averageRating  numVotes            directors  \
# 0            7.5     44742  nm0870469,nm1945519
# 1            7.3    506862            nm0500610
# 2            7.2    469715            nm0617042
# 3            6.3    288938            nm0281508
# 4            7.0    237987            nm1199107
#
#                                              writers
# 0            nm3026436,nm0870469,nm0859029,nm0859049
# 1                                nm5599654,nm2157655
# 2                                nm2219721,nm4301557
# 3  nm1988994,nm1436466,nm0391344,nm2616125,nm4731086
# 4                                          nm1199107

# %%
for i in ['genres', 'directors', 'writers']:
    df_main5[i] = df_main5[i].apply(lambda x: str(x).split(',') if pd.notna(x) else [])

df_main5.head()
# Out:
#         id     imdb_id                        title  \
# 0  1874486  tt36463894  Predator: Killer of Killers
# 1  1615420  tt12593682                 Bullet Train
# 2  1583908   tt9764362                     The Menu
# 3  1515072   tt1464335                    Uncharted
# 4  1650358  tt15791034                    Barbarian
#
#                   primaryTitle                originalTitle titleType  year  \
# 0  Predator: Killer of Killers  Predator: Killer of Killers     movie  2025
# 1                 Bullet Train                 Bullet Train     movie  2022
# 2                     The Menu                     The Menu     movie  2022
# 3                    Uncharted                    Uncharted     movie  2022
# 4                    Barbarian                    Barbarian     movie  2022
#
#    startYear  isAdult  runtimeMinutes                          genres  \
# 0       2025        0              85  [Action, Adventure, Animation]
# 1       2022        0             127      [Action, Comedy, Thriller]
# 2       2022        0             107      [Comedy, Horror, Thriller]
# 3       2022        0             116             [Action, Adventure]
# 4       2022        0             102     [Horror, Mystery, Thriller]
#
#    averageRating  numVotes               directors  \
# 0            7.5     44742  [nm0870469, nm1945519]
# 1            7.3    506862             [nm0500610]
# 2            7.2    469715             [nm0617042]
# 3            6.3    288938             [nm0281508]
# 4            7.0    237987             [nm1199107]
#
#                                              writers
# 0       [nm3026436, nm0870469, nm0859029, nm0859049]
# 1                             [nm5599654, nm2157655]
# 2                             [nm2219721, nm4301557]
# 3  [nm1988994, nm1436466, nm0391344, nm2616125, n...
# 4                                        [nm1199107]

# %% [markdown]
# #### Valores Na

# %%
resultados = {}
for i in df_main5.columns:
    resultados[i] = df_main5[i].isna().sum()
resultados
# Out:
# {'id': np.int64(0),
#  'imdb_id': np.int64(0),
#  'title': np.int64(0),
#  'primaryTitle': np.int64(2),
#  'originalTitle': np.int64(2),
#  'titleType': np.int64(2),
#  'year': np.int64(0),
#  'startYear': np.int64(4),
#  'isAdult': np.int64(2),
#  'runtimeMinutes': np.int64(6),
#  'genres': np.int64(0),
#  'averageRating': np.int64(6),
#  'numVotes': np.int64(6),
#  'directors': np.int64(0),
#  'writers': np.int64(0)}

# %%
df_main5[pd.isna(df_main5['runtimeMinutes'])]
# Out:
#             id     imdb_id                                              title  \
# 349    1623475  tt11422728  Summer of Soul (...Or, When the Revolution Cou...
# 445    1968255  tt38346012                                     The Balloonist
# 469   11040148  tt38039379                                               Stay
# 549    1775541  tt30858568                                              Mirai
# 1037   1531777   tt0154532                                        Ghar Sansar
# 1075    538039   tt9726390                 Robert Durst: An ID Murder Mystery
#
#                             primaryTitle                       originalTitle  \
# 349                                 <NA>                                <NA>
# 445                                 <NA>                                <NA>
# 469                                 STAY                                STAY
# 549                                Mirai                               Mirai
# 1037                         Ghar Sansar                         Ghar Sansar
# 1075  Robert Durst: An ID Murder Mystery  Robert Durst: An ID Murder Mystery
#
#          titleType  year  startYear  isAdult  runtimeMinutes  \
# 349            NaN  2021       <NA>     <NA>            <NA>
# 445            NaN  2025       <NA>     <NA>            <NA>
# 469          movie  2025       <NA>        0            <NA>
# 549          movie  2025       2025        0            <NA>
# 1037         movie  1986       1986        0            <NA>
# 1075  tvMiniSeries  2019       2019        0            <NA>
#
#                           genres  averageRating  numVotes  \
# 349                           []           <NA>      <NA>
# 445                           []           <NA>      <NA>
# 469                     [Horror]           <NA>      <NA>
# 549   [Action, Sci-Fi, Thriller]           <NA>      <NA>
# 1037             [Comedy, Drama]            5.4       113
# 1075                     [Crime]            6.6        68
#
#                    directors                            writers
# 349                       []                                 []
# 445                       []                                 []
# 469              [nm3520344]                        [nm3520344]
# 549   [nm6783925, nm9389259]            [nm6783925, nm12769858]
# 1037             [nm0052630]  [nm1088936, nm0434318, nm0712432]
# 1075             [nm3042526]                                 []

# %%
df_main5[pd.isna(df_main5['averageRating'])]
# Out:
#            id     imdb_id                                              title  \
# 249  11040166  tt34601055                Frankie Quiñones: Damn That's Crazy
# 349   1623475  tt11422728  Summer of Soul (...Or, When the Revolution Cou...
# 445   1968255  tt38346012                                     The Balloonist
# 469  11040148  tt38039379                                               Stay
# 549   1775541  tt30858568                                              Mirai
# 682   1839810  tt32915874                    Lilith Fair: Building a Mystery
#
#                           primaryTitle                      originalTitle  \
# 249  Untitled Frankie Quiñones Project  Untitled Frankie Quiñones Project
# 349                               <NA>                               <NA>
# 445                               <NA>                               <NA>
# 469                               STAY                               STAY
# 549                              Mirai                              Mirai
# 682    Lilith Fair: Building a Mystery    Lilith Fair: Building a Mystery
#
#     titleType  year  startYear  isAdult  runtimeMinutes  \
# 249     movie  2025       <NA>        0              60
# 349       NaN  2021       <NA>     <NA>            <NA>
# 445       NaN  2025       <NA>     <NA>            <NA>
# 469     movie  2025       <NA>        0            <NA>
# 549     movie  2025       2025        0            <NA>
# 682     movie  2025       2025        0              99
#
#                                 genres  averageRating  numVotes  \
# 249                           [Comedy]           <NA>      <NA>
# 349                                 []           <NA>      <NA>
# 445                                 []           <NA>      <NA>
# 469                           [Horror]           <NA>      <NA>
# 549         [Action, Sci-Fi, Thriller]           <NA>      <NA>
# 682  [Biography, Documentary, History]           <NA>      <NA>
#
#                   directors                  writers
# 249             [nm4399227]                       []
# 349                      []                       []
# 445                      []                       []
# 469             [nm3520344]              [nm3520344]
# 549  [nm6783925, nm9389259]  [nm6783925, nm12769858]
# 682             [nm5294992]                       []

# %% [markdown]
# #### Duplicados

# %%
df_main5.duplicated('imdb_id').sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Analisis de columnas

# %%
df_main5.describe()
# Out:
#                  id         year    startYear  isAdult  runtimeMinutes  \
# count  1.077000e+03  1077.000000       1073.0   1075.0          1071.0
# mean   1.489755e+06  2016.824513  2016.742777      0.0      105.485528
# std    7.979547e+05     9.174974     9.011032      0.0       18.856208
# min    1.867000e+03  1964.000000       1964.0      0.0             9.0
# 25%    1.336408e+06  2012.000000       2012.0      0.0            93.0
# 50%    1.607086e+06  2021.000000       2021.0      0.0           101.0
# 75%    1.692619e+06  2023.000000       2023.0      0.0           114.0
# max    1.104017e+07  2025.000000       2025.0      0.0           191.0
#
#        averageRating      numVotes
# count         1071.0        1071.0
# mean        6.185621  75777.447246
# std         1.067112  145531.19551
# min              2.0           9.0
# 25%              5.5        2798.5
# 50%              6.3       11289.0
# 75%              7.0       74196.5
# max              9.1     1113524.0

# %%
dfmain = df_main5

# %%
dfmain.to_csv('../data/imdb_hulu.csv')

# %% [markdown]
# ## Creacion Dataframe personas

# %% [markdown]
# ### Join con `imdb_principals`

# %%
df_personas1 = dfmain.merge(imdb_principals, how='left', left_on='imdb_id', right_on='tconst')
df_personas1.head()
# Out:
#         id     imdb_id                        title  \
# 0  1874486  tt36463894  Predator: Killer of Killers
# 1  1874486  tt36463894  Predator: Killer of Killers
# 2  1874486  tt36463894  Predator: Killer of Killers
# 3  1874486  tt36463894  Predator: Killer of Killers
# 4  1874486  tt36463894  Predator: Killer of Killers
#
#                   primaryTitle                originalTitle titleType  year  \
# 0  Predator: Killer of Killers  Predator: Killer of Killers     movie  2025
# 1  Predator: Killer of Killers  Predator: Killer of Killers     movie  2025
# 2  Predator: Killer of Killers  Predator: Killer of Killers     movie  2025
# 3  Predator: Killer of Killers  Predator: Killer of Killers     movie  2025
# 4  Predator: Killer of Killers  Predator: Killer of Killers     movie  2025
#
#    startYear  isAdult  runtimeMinutes  ... averageRating  numVotes  \
# 0       2025        0              85  ...           7.5     44742
# 1       2025        0              85  ...           7.5     44742
# 2       2025        0              85  ...           7.5     44742
# 3       2025        0              85  ...           7.5     44742
# 4       2025        0              85  ...           7.5     44742
#
#                 directors                                       writers  \
# 0  [nm0870469, nm1945519]  [nm3026436, nm0870469, nm0859029, nm0859049]
# 1  [nm0870469, nm1945519]  [nm3026436, nm0870469, nm0859029, nm0859049]
# 2  [nm0870469, nm1945519]  [nm3026436, nm0870469, nm0859029, nm0859049]
# 3  [nm0870469, nm1945519]  [nm3026436, nm0870469, nm0859029, nm0859049]
# 4  [nm0870469, nm1945519]  [nm3026436, nm0870469, nm0859029, nm0859049]
#
#        tconst ordering     nconst category job  characters
# 0  tt36463894      1.0  nm0000299    actor  \N   ["Vandy"]
# 1  tt36463894      2.0  nm0168339    actor  \N   ["Einar"]
# 2  tt36463894      3.0  nm0327779    actor  \N  ["Torres"]
# 3  tt36463894      4.0  nm2689910    actor  \N  ["Anders"]
# 4  tt36463894      5.0  nm7576527  actress  \N   ["Freya"]
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Eliminar columnas

# %%
df_personas2 = df_personas1[['id', 'imdb_id', 'title', 'nconst', 'ordering', 'category', 'job', 'characters', 'primaryTitle',
                             'originalTitle', 'titleType', 'year', 'startYear', 'isAdult', 'runtimeMinutes', 'genres', 'averageRating',
                             'numVotes', 'directors', 'writers']]
df_personas2.head()
# Out:
#         id     imdb_id                        title     nconst  ordering  \
# 0  1874486  tt36463894  Predator: Killer of Killers  nm0000299       1.0
# 1  1874486  tt36463894  Predator: Killer of Killers  nm0168339       2.0
# 2  1874486  tt36463894  Predator: Killer of Killers  nm0327779       3.0
# 3  1874486  tt36463894  Predator: Killer of Killers  nm2689910       4.0
# 4  1874486  tt36463894  Predator: Killer of Killers  nm7576527       5.0
#
#   category job  characters                 primaryTitle  \
# 0    actor  \N   ["Vandy"]  Predator: Killer of Killers
# 1    actor  \N   ["Einar"]  Predator: Killer of Killers
# 2    actor  \N  ["Torres"]  Predator: Killer of Killers
# 3    actor  \N  ["Anders"]  Predator: Killer of Killers
# 4  actress  \N   ["Freya"]  Predator: Killer of Killers
#
#                  originalTitle titleType  year  startYear  isAdult  \
# 0  Predator: Killer of Killers     movie  2025       2025        0
# 1  Predator: Killer of Killers     movie  2025       2025        0
# 2  Predator: Killer of Killers     movie  2025       2025        0
# 3  Predator: Killer of Killers     movie  2025       2025        0
# 4  Predator: Killer of Killers     movie  2025       2025        0
#
#    runtimeMinutes                          genres  averageRating  numVotes  \
# 0              85  [Action, Adventure, Animation]            7.5     44742
# 1              85  [Action, Adventure, Animation]            7.5     44742
# 2              85  [Action, Adventure, Animation]            7.5     44742
# 3              85  [Action, Adventure, Animation]            7.5     44742
# 4              85  [Action, Adventure, Animation]            7.5     44742
#
#                 directors                                       writers
# 0  [nm0870469, nm1945519]  [nm3026436, nm0870469, nm0859029, nm0859049]
# 1  [nm0870469, nm1945519]  [nm3026436, nm0870469, nm0859029, nm0859049]
# 2  [nm0870469, nm1945519]  [nm3026436, nm0870469, nm0859029, nm0859049]
# 3  [nm0870469, nm1945519]  [nm3026436, nm0870469, nm0859029, nm0859049]
# 4  [nm0870469, nm1945519]  [nm3026436, nm0870469, nm0859029, nm0859049]

# %% [markdown]
# ### Arreglar valores nulos y columnas

# %%
df_personas3 = df_personas2.replace(['\\N', np.nan, None], pd.NA)
df_personas3.head()
# Out:
#         id     imdb_id                        title     nconst ordering  \
# 0  1874486  tt36463894  Predator: Killer of Killers  nm0000299      1.0
# 1  1874486  tt36463894  Predator: Killer of Killers  nm0168339      2.0
# 2  1874486  tt36463894  Predator: Killer of Killers  nm0327779      3.0
# 3  1874486  tt36463894  Predator: Killer of Killers  nm2689910      4.0
# 4  1874486  tt36463894  Predator: Killer of Killers  nm7576527      5.0
#
#   category   job  characters                 primaryTitle  \
# 0    actor  <NA>   ["Vandy"]  Predator: Killer of Killers
# 1    actor  <NA>   ["Einar"]  Predator: Killer of Killers
# 2    actor  <NA>  ["Torres"]  Predator: Killer of Killers
# 3    actor  <NA>  ["Anders"]  Predator: Killer of Killers
# 4  actress  <NA>   ["Freya"]  Predator: Killer of Killers
#
#                  originalTitle titleType  year  startYear  isAdult  \
# 0  Predator: Killer of Killers     movie  2025       2025        0
# 1  Predator: Killer of Killers     movie  2025       2025        0
# 2  Predator: Killer of Killers     movie  2025       2025        0
# 3  Predator: Killer of Killers     movie  2025       2025        0
# 4  Predator: Killer of Killers     movie  2025       2025        0
#
#    runtimeMinutes                          genres  averageRating  numVotes  \
# 0              85  [Action, Adventure, Animation]            7.5     44742
# 1              85  [Action, Adventure, Animation]            7.5     44742
# 2              85  [Action, Adventure, Animation]            7.5     44742
# 3              85  [Action, Adventure, Animation]            7.5     44742
# 4              85  [Action, Adventure, Animation]            7.5     44742
#
#                 directors                                       writers
# 0  [nm0870469, nm1945519]  [nm3026436, nm0870469, nm0859029, nm0859049]
# 1  [nm0870469, nm1945519]  [nm3026436, nm0870469, nm0859029, nm0859049]
# 2  [nm0870469, nm1945519]  [nm3026436, nm0870469, nm0859029, nm0859049]
# 3  [nm0870469, nm1945519]  [nm3026436, nm0870469, nm0859029, nm0859049]
# 4  [nm0870469, nm1945519]  [nm3026436, nm0870469, nm0859029, nm0859049]

# %%
df_personas3.dtypes
# Out:
# id                   int64
# imdb_id             object
# title               object
# nconst              object
# ordering            object
# category            object
# job                 object
# characters          object
# primaryTitle        object
# originalTitle       object
# titleType         category
# year                 int64
# startYear            Int64
# isAdult              Int64
# runtimeMinutes       Int64
# genres              object
# averageRating      Float64
# numVotes             Int64
# directors           object
# writers             object
# dtype: object

# %%
df_personas3['ordering'] = df_personas3['ordering'].astype('Int64')
df_personas3['category'] = df_personas3['category'].astype('category')

# %% [markdown]
# ### Valores nulos

# %%
resultados = {}
for i in df_personas3.columns:
    resultados[i] = df_personas3[i].isna().sum()
resultados
# Out:
# {'id': np.int64(0),
#  'imdb_id': np.int64(0),
#  'title': np.int64(0),
#  'nconst': np.int64(2),
#  'ordering': np.int64(2),
#  'category': np.int64(2),
#  'job': np.int64(16487),
#  'characters': np.int64(12365),
#  'primaryTitle': np.int64(2),
#  'originalTitle': np.int64(2),
#  'titleType': np.int64(2),
#  'year': np.int64(0),
#  'startYear': np.int64(14),
#  'isAdult': np.int64(2),
#  'runtimeMinutes': np.int64(58),
#  'genres': np.int64(0),
#  'averageRating': np.int64(52),
#  'numVotes': np.int64(52),
#  'directors': np.int64(0),
#  'writers': np.int64(0)}

# %%
dfpersonas = df_personas3

# %%
dfpersonas.to_csv('../data/personas_hulu.csv')
